# %% [markdown]
# <a href="https://colab.research.google.com/github/bangaru01/C_programing/blob/main/Suman_Gamma_Arylation_V7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# Pd γ-ARYLATION
# COMPLETE LIGAND DESCRIPTOR + YIELD CORRELATION ANALYSIS
#
# LIGAND ATOMS : 17 -> LAST
# Pd ATOM       : 1
# Pd-X CUTOFF   : 2.00 - 2.40 Å
#
# PROJECT: Pd γ-arylation ONLY
# ============================================================


# ============================================================
# 1. INSTALL PYTHON PACKAGES
# ============================================================

# !pip -q install morfeus-ml pandas numpy scipy openpyxl matplotlib seaborn


# ============================================================
# 2. IMPORTS
# ============================================================

import os
import re
import glob
import shutil
import subprocess
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr, spearmanr

from morfeus import (
    SASA,
    SolidAngle,
    BuriedVolume,
    Sterimol,
    BiteAngle,
    Pyramidalization,
    XTB
)

warnings.filterwarnings("ignore")


# ============================================================
# 3. GOOGLE DRIVE
# ============================================================

from google.colab import drive

drive.mount("/content/drive")


# ============================================================
# 4. USER SETTINGS
# ============================================================

XYZ_FOLDER = "/content/drive/MyDrive/Suman_files"

OUTPUT_FOLDER = (
    "/content/drive/MyDrive/"
    "Pd_gamma_arylation_RESULTS"
)

os.makedirs(
    OUTPUT_FOLDER,
    exist_ok=True
)


# ------------------------------------------------------------
# Output Excel
# ------------------------------------------------------------

FINAL_EXCEL = os.path.join(
    OUTPUT_FOLDER,
    "Pd_gamma_arylation_COMPLETE_ANALYSIS.xlsx"
)


# ============================================================
# CHEMICAL SETTINGS
# ============================================================

PD_ATOM = 1

LIGAND_START = 17

# IMPORTANT:
# EXACT coordination criterion requested
PD_DONOR_MIN = 2.00
PD_DONOR_MAX = 2.40

DONOR_ELEMENTS = {
    "N",
    "P",
    "S",
    "O"
}


# ============================================================
# MORFEUS SETTINGS
# ============================================================

SASA_PROBE_RADIUS = 1.4

VBUR_RADII = [
    3.0,
    3.5,
    4.0
]

VBUR_RADII_TYPE = "bondi"

SOLID_ANGLE_RADII_TYPE = "bondi"

STERIMOL_RADII_TYPE = "crc"


# ============================================================
# xTB SETTINGS
# ============================================================

XTB_METHOD = 2                 # GFN2-xTB
XTB_CHARGE = 0
XTB_N_UNPAIRED = 0
XTB_PROCESSES = 2


# ============================================================
# OUTLIER SETTINGS
# ============================================================

OUTLIER_FRACTION_LIMIT = 0.10

IQR_MULTIPLIER = 1.5

MAD_Z_LIMIT = 3.5


# ============================================================
# HIGH CORRELATION THRESHOLD
# ============================================================

HIGH_CORR_THRESHOLD = 0.80


# ============================================================
# 5. YIELD DATA
# ============================================================

YIELD_DATA = {

    "L7": 0,
    "L8": 0,
    "L9": 0,
    "L10": 0,
    "L11": 0,
    "L12": 0,
    "L13": 0,
    "L14": 0,
    "L15": 0,

    "L16": 12,
    "L17": 53,
    "L18": 46,
    "L19": 67,
    "L20": 40,
    "L21": 31,

    "L22": 0,
    "L23": 0,
    "L24": 0,
    "L25": 0
}


# ============================================================
# 6. CREATE PLOT FOLDERS
# ============================================================

PLOT_FOLDER = os.path.join(
    OUTPUT_FOLDER,
    "PLOTS"
)

SCATTER_FOLDER = os.path.join(
    PLOT_FOLDER,
    "Yield_vs_Descriptors"
)

BOX_FOLDER = os.path.join(
    PLOT_FOLDER,
    "Descriptor_Boxplots"
)

os.makedirs(PLOT_FOLDER, exist_ok=True)
os.makedirs(SCATTER_FOLDER, exist_ok=True)
os.makedirs(BOX_FOLDER, exist_ok=True)


# ============================================================
# 7. xTB CHECK / INSTALL
# ============================================================

print("=" * 80)
print("CHECKING xTB")
print("=" * 80)

xtb_path = shutil.which("xtb")

if xtb_path is None:

    print("\n✗ xTB executable not found.")
    print("Installing xTB binary...\n")

    xtb_archive = "/content/xtb.tar.xz"

    subprocess.run(
        [
            "wget",
            "-q",
            "--show-progress",
            "https://github.com/grimme-lab/xtb/releases/latest/download/xtb-6.7.1-linux-x86_64.tar.xz",
            "-O",
            xtb_archive
        ],
        check=True
    )

    subprocess.run(
        [
            "tar",
            "-xf",
            xtb_archive,
            "-C",
            "/content"
        ],
        check=True
    )

    xtb_dirs = sorted([
        d
        for d in os.listdir("/content")
        if d.startswith("xtb-")
        and os.path.isdir(
            os.path.join("/content", d)
        )
    ])

    if not xtb_dirs:

        raise RuntimeError(
            "xTB archive extracted but "
            "xTB directory was not found."
        )

    xtb_dir = os.path.join(
        "/content",
        xtb_dirs[-1]
    )

    xtb_bin = os.path.join(
        xtb_dir,
        "bin"
    )

    xtb_executable = os.path.join(
        xtb_bin,
        "xtb"
    )

    if not os.path.exists(
        xtb_executable
    ):

        raise RuntimeError(
            f"xTB executable not found:\n"
            f"{xtb_executable}"
        )

    os.environ["PATH"] = (
        xtb_bin
        + ":"
        + os.environ["PATH"]
    )

    os.environ["XTBHOME"] = xtb_dir

    print("\n✓ xTB installed")
    print(
        "Executable:",
        xtb_executable
    )


xtb_path = shutil.which("xtb")

if xtb_path is None:

    raise RuntimeError(
        "xTB is still unavailable."
    )


print("\n" + "=" * 80)
print("xTB VERIFICATION")
print("=" * 80)

print(
    "xTB executable:",
    xtb_path
)

version = subprocess.run(
    ["xtb", "--version"],
    capture_output=True,
    text=True
)

print(version.stdout)

print("=" * 80)
print("✓ xTB READY")
print("=" * 80)


# ============================================================
# 8. HELPER FUNCTIONS
# ============================================================

def finite(value):

    try:

        value = float(value)

        if np.isfinite(value):
            return value

    except Exception:
        pass

    return np.nan


def distance(a, b):

    return float(
        np.linalg.norm(
            np.asarray(a)
            -
            np.asarray(b)
        )
    )


def angle_deg(a, b, c):

    v1 = (
        np.asarray(a)
        -
        np.asarray(b)
    )

    v2 = (
        np.asarray(c)
        -
        np.asarray(b)
    )

    n1 = np.linalg.norm(v1)
    n2 = np.linalg.norm(v2)

    if n1 == 0 or n2 == 0:
        return np.nan

    cosine = np.dot(v1, v2) / (
        n1 * n2
    )

    cosine = np.clip(
        cosine,
        -1.0,
        1.0
    )

    return float(
        np.degrees(
            np.arccos(cosine)
        )
    )


def clean_ligand_name(filename):

    base = os.path.basename(filename)

    base = re.sub(
        r"\.xyz$",
        "",
        base,
        flags=re.IGNORECASE
    )

    base = re.sub(
        r"[_-](new|opt|optimized)$",
        "",
        base,
        flags=re.IGNORECASE
    )

    match = re.search(
        r"L\d+",
        base,
        flags=re.IGNORECASE
    )

    if match:
        return match.group(0).upper()

    return base


def safe_filename(text):

    return re.sub(
        r"[^A-Za-z0-9_.-]+",
        "_",
        str(text)
    )


# ============================================================
# 9. XYZ READER
# ============================================================

def read_xyz_file(filepath):

    with open(
        filepath,
        "r",
        encoding="utf-8"
    ) as f:

        lines = [
            x.strip()
            for x in f
            if x.strip()
        ]

    if len(lines) < 3:

        raise ValueError(
            "XYZ file too short."
        )

    n_atoms = int(
        lines[0].split()[0]
    )

    atom_lines = lines[2:]

    if len(atom_lines) < n_atoms:

        raise ValueError(
            "Number of coordinate lines "
            "is smaller than atom count."
        )

    elements = []
    coordinates = []

    for line in atom_lines[:n_atoms]:

        parts = line.split()

        elements.append(
            parts[0]
        )

        coordinates.append([
            float(parts[1]),
            float(parts[2]),
            float(parts[3])
        ])

    coordinates = np.asarray(
        coordinates,
        dtype=float
    )

    return elements, coordinates


# ============================================================
# 10. FIND XYZ FILES
# ============================================================

xyz_files = sorted(
    glob.glob(
        os.path.join(
            XYZ_FOLDER,
            "*.xyz"
        )
    )
)

print("\n" + "=" * 80)
print("XYZ FILES")
print("=" * 80)

print(
    f"Found {len(xyz_files)} XYZ files."
)

if len(xyz_files) == 0:

    raise FileNotFoundError(
        f"No XYZ files found in:\n"
        f"{XYZ_FOLDER}"
    )

for f in xyz_files:
    print(
        " ",
        os.path.basename(f)
    )


# ============================================================
# 11. COVALENT RADII
# ============================================================

COVALENT_RADII = {

    "H": 0.31,
    "C": 0.76,
    "N": 0.71,
    "O": 0.66,
    "F": 0.57,

    "P": 1.07,
    "S": 1.05,

    "Cl": 1.02,
    "Br": 1.20,
    "I": 1.39,

    "Pd": 1.39
}


# ============================================================
# 12. COVALENT NEIGHBORS
# ============================================================

def covalent_neighbors(
    elements,
    coordinates,
    atom_id,
    allowed_indices=None,
    scale=1.25
):

    if allowed_indices is None:

        allowed_indices = range(
            1,
            len(elements) + 1
        )

    atom_element = elements[
        atom_id - 1
    ]

    if atom_element not in COVALENT_RADII:

        return []

    r1 = COVALENT_RADII[
        atom_element
    ]

    result = []

    for j in allowed_indices:

        if j == atom_id:
            continue

        element_j = elements[
            j - 1
        ]

        if element_j not in COVALENT_RADII:
            continue

        r2 = COVALENT_RADII[
            element_j
        ]

        d = distance(
            coordinates[atom_id - 1],
            coordinates[j - 1]
        )

        cutoff = scale * (
            r1 + r2
        )

        if d <= cutoff:

            result.append(
                (j, d)
            )

    return sorted(
        result,
        key=lambda x: x[1]
    )


# ============================================================
# 13. Pd DONOR IDENTIFICATION
#
# ONLY ligand atoms 17 -> LAST
# ONLY N/P/S/O
# ONLY 2.00 -> 2.40 Å
# ============================================================

def find_pd_donors(
    elements,
    coordinates
):

    pd_xyz = coordinates[
        PD_ATOM - 1
    ]

    candidates = []

    for atom_id in range(
        LIGAND_START,
        len(elements) + 1
    ):

        element = elements[
            atom_id - 1
        ]

        if element not in DONOR_ELEMENTS:
            continue

        d = distance(
            pd_xyz,
            coordinates[
                atom_id - 1
            ]
        )

        candidates.append({
            "Atom": atom_id,
            "Element": element,
            "Pd_Distance_A": d
        })

    qualifying = [

        x for x in candidates

        if (
            PD_DONOR_MIN
            <=
            x["Pd_Distance_A"]
            <=
            PD_DONOR_MAX
        )
    ]

    qualifying = sorted(
        qualifying,
        key=lambda x:
        x["Pd_Distance_A"]
    )

    return candidates, qualifying


# ============================================================
# 14. BUILD LIGAND GRAPH
# ============================================================

def build_ligand_graph(
    elements,
    coordinates
):

    ligand_indices = list(
        range(
            LIGAND_START,
            len(elements) + 1
        )
    )

    graph = {
        i: set()
        for i in ligand_indices
    }

    for i in ligand_indices:

        neighbors = covalent_neighbors(
            elements,
            coordinates,
            i,
            allowed_indices=ligand_indices
        )

        for j, d in neighbors:

            graph[i].add(j)
            graph[j].add(i)

    return graph


# ============================================================
# 15. SHORTEST DONOR-DONOR LIGAND PATH
# ============================================================

def shortest_ligand_path(
    graph,
    start,
    end
):

    if start is None or end is None:
        return None

    queue = [
        (
            start,
            [start]
        )
    ]

    visited = {
        start
    }

    while queue:

        current, path = queue.pop(0)

        if current == end:
            return path

        for neighbor in sorted(
            graph.get(current, [])
        ):

            if neighbor not in visited:

                visited.add(
                    neighbor
                )

                queue.append(
                    (
                        neighbor,
                        path + [neighbor]
                    )
                )

    return None


# ============================================================
# 16. PALLADACYCLE CLASSIFICATION
#
# PROJECT DEFINITION:
#
# L7-L15  : Pd-N-C-C-N-Pd
#            ligand path contains 4 atoms
#            => 4-membered project class
#
# L16-L25 : Pd-N-C-C-C-N-Pd
#            ligand path contains 5 atoms
#            => 5-membered project class
# ============================================================

def determine_palladacycle(
    ligand_name,
    elements,
    coordinates,
    donor1,
    donor2
):

    result = {

        "Palladacycle_Type": None,

        "Palladacycle_Ring_Size": np.nan,

        "Palladacycle_Ligand_Path": None,

        "Palladacycle_Path_Atom_Count": np.nan,

        "Palladacycle_Path_Bond_Mean_A": np.nan,

        "Palladacycle_Path_Bond_SD_A": np.nan,

        "Palladacycle_Path_Bond_CV": np.nan,

        "Expected_Palladacycle_Type": None,

        "Palladacycle_Type_Check": None
    }

    # --------------------------------------------------------
    # Expected project classification
    # --------------------------------------------------------

    match = re.search(
        r"L(\d+)",
        ligand_name,
        flags=re.IGNORECASE
    )

    if match:

        number = int(
            match.group(1)
        )

        if 7 <= number <= 15:

            result[
                "Expected_Palladacycle_Type"
            ] = "4-membered"

        elif 16 <= number <= 25:

            result[
                "Expected_Palladacycle_Type"
            ] = "5-membered"


    if donor1 is None or donor2 is None:

        result[
            "Palladacycle_Type"
        ] = "NOT_AVAILABLE"

        return result


    graph = build_ligand_graph(
        elements,
        coordinates
    )

    path = shortest_ligand_path(
        graph,
        donor1,
        donor2
    )

    if path is None:

        result[
            "Palladacycle_Type"
        ] = "NOT_FOUND"

        return result


    result[
        "Palladacycle_Ligand_Path"
    ] = "-".join(
        map(str, path)
    )

    path_count = len(path)

    result[
        "Palladacycle_Path_Atom_Count"
    ] = path_count

    # --------------------------------------------------------
    # IMPORTANT:
    # Project ring-size convention excludes Pd.
    # --------------------------------------------------------

    if path_count == 4:

        result[
            "Palladacycle_Ring_Size"
        ] = 4

        result[
            "Palladacycle_Type"
        ] = "4-membered"

    elif path_count == 5:

        result[
            "Palladacycle_Ring_Size"
        ] = 5

        result[
            "Palladacycle_Type"
        ] = "5-membered"

    else:

        result[
            "Palladacycle_Type"
        ] = f"OTHER_{path_count}"

    # --------------------------------------------------------
    # Path bond geometry
    # --------------------------------------------------------

    bond_lengths = []

    for i in range(
        len(path) - 1
    ):

        a = path[i]
        b = path[i + 1]

        d = distance(
            coordinates[a - 1],
            coordinates[b - 1]
        )

        bond_lengths.append(d)


    if bond_lengths:

        mean_bond = np.mean(
            bond_lengths
        )

        sd_bond = np.std(
            bond_lengths,
            ddof=0
        )

        result[
            "Palladacycle_Path_Bond_Mean_A"
        ] = mean_bond

        result[
            "Palladacycle_Path_Bond_SD_A"
        ] = sd_bond

        if mean_bond != 0:

            result[
                "Palladacycle_Path_Bond_CV"
            ] = (
                sd_bond /
                mean_bond
            )


    expected = result[
        "Expected_Palladacycle_Type"
    ]

    actual = result[
        "Palladacycle_Type"
    ]

    if expected is None:

        result[
            "Palladacycle_Type_Check"
        ] = "NO_EXPECTATION"

    elif expected == actual:

        result[
            "Palladacycle_Type_Check"
        ] = "PASS"

    else:

        result[
            "Palladacycle_Type_Check"
        ] = "CHECK"


    return result


# ============================================================
# 17. STERIC DESCRIPTORS
# ============================================================

def calculate_steric(
    elements,
    coordinates,
    donor1
):

    result = {}

    ligand_indices = list(
        range(
            LIGAND_START,
            len(elements) + 1
        )
    )

    ligand_elements = [
        elements[i - 1]
        for i in ligand_indices
    ]

    ligand_coordinates = coordinates[
        np.array(ligand_indices) - 1
    ]

    # --------------------------------------------------------
    # Maximum ligand extension
    # --------------------------------------------------------

    max_extension = 0.0

    for i in range(
        len(ligand_coordinates)
    ):

        for j in range(
            i + 1,
            len(ligand_coordinates)
        ):

            d = distance(
                ligand_coordinates[i],
                ligand_coordinates[j]
            )

            max_extension = max(
                max_extension,
                d
            )

    result[
        "Ligand_Maximum_Extension_A"
    ] = finite(
        max_extension
    )


    # --------------------------------------------------------
    # SASA
    # --------------------------------------------------------

    try:

        sasa = SASA(
            ligand_elements,
            ligand_coordinates,
            probe_radius=SASA_PROBE_RADIUS
        )

        result[
            "Ligand_SASA_A2"
        ] = finite(
            sasa.area
        )

        result[
            "Ligand_SASA_Volume_A3"
        ] = finite(
            sasa.volume
        )

    except Exception as e:

        result[
            "SASA_Warning"
        ] = str(e)


    # --------------------------------------------------------
    # Solid angle
    #
    # ligand-only:
    # reduced system = Pd + ligand
    # --------------------------------------------------------

    try:

        reduced_elements = (
            ["Pd"]
            +
            ligand_elements
        )

        reduced_coordinates = np.vstack([
            coordinates[
                PD_ATOM - 1
            ],
            ligand_coordinates
        ])

        sa = SolidAngle(
            reduced_elements,
            reduced_coordinates,
            metal_index=1,
            radii_type=SOLID_ANGLE_RADII_TYPE
        )

        result[
            "Ligand_Solid_Angle_sr"
        ] = finite(
            sa.solid_angle
        )

        result[
            "Ligand_Solid_Cone_Angle_deg"
        ] = finite(
            sa.cone_angle
        )

        result[
            "Ligand_Solid_G_percent"
        ] = finite(
            sa.G
        )

    except Exception as e:

        result[
            "SolidAngle_Warning"
        ] = str(e)


    # --------------------------------------------------------
    # Buried volume
    # --------------------------------------------------------

    excluded_atoms = [

        i
        for i in range(
            1,
            len(elements) + 1
        )

        if (
            i != PD_ATOM
            and
            i not in ligand_indices
        )
    ]


    for radius in VBUR_RADII:

        key = (
            f"Ligand_%Vbur_{radius:.1f}A"
        )

        try:

            bv = BuriedVolume(
                elements,
                coordinates,
                metal_index=PD_ATOM,
                excluded_atoms=excluded_atoms,
                radius=radius,
                include_hs=False,
                radii_type=VBUR_RADII_TYPE
            )

            result[key] = finite(
                bv.fraction_buried_volume
                * 100.0
            )

        except Exception as e:

            result[
                key
            ] = np.nan

            result[
                f"{key}_Warning"
            ] = str(e)


    # --------------------------------------------------------
    # Pd-oriented custom Sterimol
    #
    # IMPORTANT:
    # This is NOT standard H-dummy Sterimol.
    # It is a Pd-oriented custom descriptor.
    # --------------------------------------------------------

    if donor1 is not None:

        try:

            reduced_elements = (
                ["Pd"]
                +
                ligand_elements
            )

            reduced_coordinates = np.vstack([
                coordinates[
                    PD_ATOM - 1
                ],
                ligand_coordinates
            ])

            original_to_reduced = {
                original: i + 2
                for i, original
                in enumerate(
                    ligand_indices
                )
            }

            attached_index = (
                original_to_reduced[
                    donor1
                ]
            )

            ster = Sterimol(
                reduced_elements,
                reduced_coordinates,
                dummy_index=1,
                attached_index=attached_index,
                radii_type=STERIMOL_RADII_TYPE
            )

            result[
                "Pd_Oriented_Sterimol_B1_A"
            ] = finite(
                ster.B_1_value
            )

            result[
                "Pd_Oriented_Sterimol_B5_A"
            ] = finite(
                ster.B_5_value
            )

            result[
                "Pd_Oriented_Sterimol_L_A"
            ] = finite(
                ster.L_value
            )

        except Exception as e:

            result[
                "Sterimol_Warning"
            ] = str(e)


    return result


# ============================================================
# 18. COORDINATION DESCRIPTORS
# ============================================================

def calculate_coordination(
    elements,
    coordinates,
    donor1,
    donor2
):

    result = {}

    if donor1 is None:

        return {
            "Pd_Donor1_Distance_A": np.nan,
            "Pd_Donor2_Distance_A": np.nan,
            "Average_Pd_Donor_Distance_A": np.nan,
            "Delta_Pd_Donor_Distance_A": np.nan,
            "Pd_Donor_Distance_Ratio": np.nan,
            "Bite_Angle_deg": np.nan,
            "Donor1_Donor2_Distance_A": np.nan,
            "Pd_Coordination_Distortion_A": np.nan
        }


    pd_xyz = coordinates[
        PD_ATOM - 1
    ]


    d1 = distance(
        pd_xyz,
        coordinates[
            donor1 - 1
        ]
    )


    result[
        "Pd_Donor1_Distance_A"
    ] = d1


    if donor2 is not None:

        d2 = distance(
            pd_xyz,
            coordinates[
                donor2 - 1
            ]
        )

        result[
            "Pd_Donor2_Distance_A"
        ] = d2

        avg = (
            d1 + d2
        ) / 2.0

        delta = abs(
            d1 - d2
        )

        result[
            "Average_Pd_Donor_Distance_A"
        ] = avg

        result[
            "Delta_Pd_Donor_Distance_A"
        ] = delta

        if min(d1, d2) > 0:

            result[
                "Pd_Donor_Distance_Ratio"
            ] = (
                max(d1, d2)
                /
                min(d1, d2)
            )


        result[
            "Pd_Coordination_Distortion_A"
        ] = np.sqrt(
            (
                (d1 - avg) ** 2
                +
                (d2 - avg) ** 2
            ) / 2.0
        )


        result[
            "Donor1_Donor2_Distance_A"
        ] = distance(
            coordinates[
                donor1 - 1
            ],
            coordinates[
                donor2 - 1
            ]
        )

        try:

            bite = BiteAngle(
                coordinates,
                PD_ATOM,
                donor1,
                donor2
            )

            result[
                "Bite_Angle_deg"
            ] = finite(
                bite.angle
            )

        except Exception as e:

            result[
                "Bite_Angle_deg"
            ] = np.nan

            result[
                "Bite_Angle_Warning"
            ] = str(e)

    else:

        result[
            "Pd_Donor2_Distance_A"
        ] = np.nan

        result[
            "Average_Pd_Donor_Distance_A"
        ] = np.nan

        result[
            "Delta_Pd_Donor_Distance_A"
        ] = np.nan

        result[
            "Pd_Donor_Distance_Ratio"
        ] = np.nan

        result[
            "Pd_Coordination_Distortion_A"
        ] = np.nan

        result[
            "Donor1_Donor2_Distance_A"
        ] = np.nan

        result[
            "Bite_Angle_deg"
        ] = np.nan


    return result


# ============================================================
# 19. PYRAMIDALIZATION
# ============================================================

def calculate_pyramidalization(
    elements,
    coordinates,
    donor1,
    donor2
):

    result = {}

    ligand_indices = list(
        range(
            LIGAND_START,
            len(elements) + 1
        )
    )


    def calculate_one(
        donor,
        prefix
    ):

        if donor is None:

            return {

                f"{prefix}_Neighbor_Count":
                    np.nan,

                f"{prefix}_P":
                    np.nan,

                f"{prefix}_P_Angle_deg":
                    np.nan,

                f"{prefix}_P_Warning":
                    "Donor unavailable."
            }


        neighbors = covalent_neighbors(
            elements,
            coordinates,
            donor,
            allowed_indices=ligand_indices
        )

        neighbor_ids = [
            x[0]
            for x in neighbors
        ]

        out = {

            f"{prefix}_Neighbor_Count":
                len(neighbor_ids)
        }


        # ----------------------------------------------------
        # Need at least 3 neighbors
        # ----------------------------------------------------

        if len(neighbor_ids) < 3:

            out[
                f"{prefix}_P"
            ] = np.nan

            out[
                f"{prefix}_P_Angle_deg"
            ] = np.nan

            out[
                f"{prefix}_P_Warning"
            ] = (
                f"{len(neighbor_ids)} "
                "covalent neighbors; "
                "pyramidalization not safely defined."
            )

            return out


        selected = neighbor_ids[:3]


        try:

            pyr = Pyramidalization(
                coordinates,
                donor,
                neighbor_indices=selected
            )

            out[
                f"{prefix}_P"
            ] = finite(
                pyr.P
            )

            out[
                f"{prefix}_P_Angle_deg"
            ] = finite(
                pyr.P_angle
            )

        except Exception as e:

            out[
                f"{prefix}_P"
            ] = np.nan

            out[
                f"{prefix}_P_Angle_deg"
            ] = np.nan

            out[
                f"{prefix}_P_Warning"
            ] = str(e)


        return out


    d1 = calculate_one(
        donor1,
        "Donor1_Pyramidalization"
    )

    d2 = calculate_one(
        donor2,
        "Donor2_Pyramidalization"
    )

    result.update(d1)
    result.update(d2)


    # --------------------------------------------------------
    # Average / delta P
    # --------------------------------------------------------

    p1 = result.get(
        "Donor1_Pyramidalization_P",
        np.nan
    )

    p2 = result.get(
        "Donor2_Pyramidalization_P",
        np.nan
    )

    if (
        pd.notna(p1)
        and
        pd.notna(p2)
    ):

        result[
            "Average_Pyramidalization_P"
        ] = (
            p1 + p2
        ) / 2.0

        result[
            "Delta_Pyramidalization_P"
        ] = abs(
            p1 - p2
        )

    else:

        result[
            "Average_Pyramidalization_P"
        ] = np.nan

        result[
            "Delta_Pyramidalization_P"
        ] = np.nan


    # --------------------------------------------------------
    # Average / delta P angle
    # --------------------------------------------------------

    a1 = result.get(
        "Donor1_Pyramidalization_P_Angle_deg",
        np.nan
    )

    a2 = result.get(
        "Donor2_Pyramidalization_P_Angle_deg",
        np.nan
    )

    if (
        pd.notna(a1)
        and
        pd.notna(a2)
    ):

        result[
            "Average_Pyramidalization_Angle_deg"
        ] = (
            a1 + a2
        ) / 2.0

        result[
            "Delta_Pyramidalization_Angle_deg"
        ] = abs(
            a1 - a2
        )

    else:

        result[
            "Average_Pyramidalization_Angle_deg"
        ] = np.nan

        result[
            "Delta_Pyramidalization_Angle_deg"
        ] = np.nan


    return result


# ============================================================
# 20. xTB ELECTRONIC DESCRIPTORS
#
# IMPORTANT:
# ONLY ligand atoms 17 -> LAST
#
# Pd is NOT included in isolated ligand xTB.
# ============================================================

def calculate_xtb(
    elements,
    coordinates,
    donor1,
    donor2
):

    result = {}

    ligand_indices = list(
        range(
            LIGAND_START,
            len(elements) + 1
        )
    )

    ligand_elements = [
        elements[i - 1]
        for i in ligand_indices
    ]

    ligand_coordinates = coordinates[
        np.array(ligand_indices) - 1
    ]


    try:

        xtb = XTB(
            ligand_elements,
            ligand_coordinates,
            method=XTB_METHOD,
            charge=XTB_CHARGE,
            n_unpaired=XTB_N_UNPAIRED,
            n_processes=XTB_PROCESSES
        )


        # ----------------------------------------------------
        # Charges
        # ----------------------------------------------------

        charges = xtb.get_charges(
            model="Mulliken"
        )

        result[
            "XTB_Ligand_Charge_Sum"
        ] = finite(
            np.sum(charges)
        )


        # ----------------------------------------------------
        # HOMO / LUMO
        # ----------------------------------------------------

        result[
            "XTB_HOMO_eV"
        ] = finite(
            xtb.get_homo(
                unit="eV"
            )
        )

        result[
            "XTB_LUMO_eV"
        ] = finite(
            xtb.get_lumo(
                unit="eV"
            )
        )

        result[
            "XTB_HOMO_LUMO_Gap_eV"
        ] = finite(
            xtb.get_homo_lumo_gap()
        )


        # ----------------------------------------------------
        # Fermi
        # ----------------------------------------------------

        result[
            "XTB_Fermi_Level_eV"
        ] = finite(
            xtb.get_fermi_level()
        )


        # ----------------------------------------------------
        # IP / EA
        # ----------------------------------------------------

        result[
            "XTB_IP_eV"
        ] = finite(
            xtb.get_ip(
                corrected=True
            )
        )

        result[
            "XTB_EA_eV"
        ] = finite(
            xtb.get_ea(
                corrected=True
            )
        )


        # ----------------------------------------------------
        # Chemical potential
        # ----------------------------------------------------

        result[
            "XTB_Chemical_Potential_eV"
        ] = finite(
            xtb.get_chemical_potential(
                corrected=True
            )
        )


        # ----------------------------------------------------
        # Electronegativity
        # ----------------------------------------------------

        result[
            "XTB_Electronegativity_eV"
        ] = finite(
            xtb.get_electronegativity(
                corrected=True
            )
        )


        # ----------------------------------------------------
        # Hardness / softness
        # ----------------------------------------------------

        result[
            "XTB_Hardness_eV"
        ] = finite(
            xtb.get_hardness()
        )

        result[
            "XTB_Softness"
        ] = finite(
            xtb.get_softness()
        )


        # ----------------------------------------------------
        # Global electrophilicity / nucleophilicity
        # ----------------------------------------------------

        try:

            result[
                "XTB_Electrophilicity"
            ] = finite(
                xtb.get_global_descriptor(
                    "electrophilicity",
                    corrected=True
                )
            )

        except Exception:

            result[
                "XTB_Electrophilicity"
            ] = np.nan


        try:

            result[
                "XTB_Nucleophilicity"
            ] = finite(
                xtb.get_global_descriptor(
                    "nucleophilicity",
                    corrected=True
                )
            )

        except Exception:

            result[
                "XTB_Nucleophilicity"
            ] = np.nan


        # ----------------------------------------------------
        # Dipole
        # ----------------------------------------------------

        result[
            "XTB_Dipole_Debye"
        ] = finite(
            xtb.get_dipole_moment(
                unit="debye"
            )
        )


        # ----------------------------------------------------
        # Polarizability
        # ----------------------------------------------------

        try:

            result[
                "XTB_Polarizability"
            ] = finite(
                xtb.get_molecular_polarizability()
            )

        except Exception:

            result[
                "XTB_Polarizability"
            ] = np.nan


        # ----------------------------------------------------
        # NFOD
        # ----------------------------------------------------

        try:

            result[
                "XTB_NFOD"
            ] = finite(
                xtb.get_nfod()
            )

        except Exception:

            result[
                "XTB_NFOD"
            ] = np.nan


        # ----------------------------------------------------
        # Donor charges
        #
        # Original atom ID -> isolated ligand index
        # ----------------------------------------------------

        original_to_xtb = {
            original: i
            for i, original
            in enumerate(
                ligand_indices
            )
        }

        if donor1 is not None:

            idx1 = original_to_xtb[
                donor1
            ]

            result[
                "Donor1_Mulliken_Charge"
            ] = finite(
                charges[idx1]
            )

        else:

            result[
                "Donor1_Mulliken_Charge"
            ] = np.nan


        if donor2 is not None:

            idx2 = original_to_xtb[
                donor2
            ]

            result[
                "Donor2_Mulliken_Charge"
            ] = finite(
                charges[idx2]
            )

        else:

            result[
                "Donor2_Mulliken_Charge"
            ] = np.nan


        # ----------------------------------------------------
        # Donor charge summary
        # ----------------------------------------------------

        q1 = result.get(
            "Donor1_Mulliken_Charge",
            np.nan
        )

        q2 = result.get(
            "Donor2_Mulliken_Charge",
            np.nan
        )

        if (
            pd.notna(q1)
            and
            pd.notna(q2)
        ):

            result[
                "Average_Donor_Charge"
            ] = (
                q1 + q2
            ) / 2.0

            result[
                "Delta_Donor_Charge"
            ] = abs(
                q1 - q2
            )

            result[
                "Donor_Charge_Sum"
            ] = q1 + q2

        else:

            result[
                "Average_Donor_Charge"
            ] = np.nan

            result[
                "Delta_Donor_Charge"
            ] = np.nan

            result[
                "Donor_Charge_Sum"
            ] = np.nan


    except Exception as e:

        result[
            "XTB_Warning"
        ] = str(e)


    return result


# ============================================================
# 21. OPTIONAL NBO TABLE
#
# XYZ alone cannot calculate NBO E(2).
#
# If you have NBO values, prepare a CSV/XLSX with:
#
# Ligand
# NBO_Donor1_to_Pd_E2_kcal
# NBO_Donor2_to_Pd_E2_kcal
# NBO_Total_Ligand_to_Pd_E2_kcal
# NBO_Max_Ligand_to_Pd_E2_kcal
# NBO_Donor_Orbital_Gap_eV
#
# Set NBO_TABLE_FILE below.
# ============================================================

NBO_TABLE_FILE = None

# Example:
#
# NBO_TABLE_FILE = (
#     "/content/drive/MyDrive/"
#     "Pd_gamma_arylation_NBO.xlsx"
# )


def load_nbo_table():

    if NBO_TABLE_FILE is None:

        return pd.DataFrame()

    if not os.path.exists(
        NBO_TABLE_FILE
    ):

        print(
            "\nWARNING: NBO table not found:"
        )

        print(
            NBO_TABLE_FILE
        )

        return pd.DataFrame()


    if NBO_TABLE_FILE.lower().endswith(
        ".csv"
    ):

        nbo = pd.read_csv(
            NBO_TABLE_FILE
        )

    else:

        nbo = pd.read_excel(
            NBO_TABLE_FILE
        )


    if "Ligand" not in nbo.columns:

        raise ValueError(
            "NBO table must contain "
            "a 'Ligand' column."
        )


    nbo["Ligand_ID"] = (
        nbo["Ligand"]
        .astype(str)
        .str.extract(
            r"(L\d+)",
            expand=False
        )
        .str.upper()
    )

    return nbo


nbo_table = load_nbo_table()


# ============================================================
# 22. PROCESS ONE XYZ
# ============================================================

def process_xyz(filepath):

    ligand_name = clean_ligand_name(
        filepath
    )

    elements, coordinates = (
        read_xyz_file(filepath)
    )


    row = {

        "Ligand": ligand_name,

        "XYZ_File":
            os.path.basename(filepath),

        "N_Atoms":
            len(elements),

        "Pd_Atom":
            PD_ATOM,

        "Ligand_Start_Atom":
            LIGAND_START,

        "Pd_Donor_Min_A":
            PD_DONOR_MIN,

        "Pd_Donor_Max_A":
            PD_DONOR_MAX
    }


    # ========================================================
    # DONORS
    # ========================================================

    candidates, qualifying = (
        find_pd_donors(
            elements,
            coordinates
        )
    )


    row[
        "Number_of_Donor_Candidates"
    ] = len(candidates)

    row[
        "Number_of_Qualifying_Pd_Donors"
    ] = len(qualifying)


    # --------------------------------------------------------
    # Donor 1
    # --------------------------------------------------------

    if len(qualifying) >= 1:

        donor1 = qualifying[0]["Atom"]

        row[
            "Donor1_Atom"
        ] = donor1

        row[
            "Donor1_Element"
        ] = qualifying[0]["Element"]

        row[
            "Pd_Donor1_Distance_A"
        ] = qualifying[0][
            "Pd_Distance_A"
        ]

    else:

        donor1 = None

        row[
            "Donor1_Atom"
        ] = np.nan

        row[
            "Donor1_Element"
        ] = None

        row[
            "Pd_Donor1_Distance_A"
        ] = np.nan


    # --------------------------------------------------------
    # Donor 2
    # --------------------------------------------------------

    if len(qualifying) >= 2:

        donor2 = qualifying[1]["Atom"]

        row[
            "Donor2_Atom"
        ] = donor2

        row[
            "Donor2_Element"
        ] = qualifying[1]["Element"]

        row[
            "Pd_Donor2_Distance_A"
        ] = qualifying[1][
            "Pd_Distance_A"
        ]

    else:

        donor2 = None

        row[
            "Donor2_Atom"
        ] = np.nan

        row[
            "Donor2_Element"
        ] = None

        row[
            "Pd_Donor2_Distance_A"
        ] = np.nan


    # --------------------------------------------------------
    # Donor selection QC
    # --------------------------------------------------------

    if len(qualifying) == 2:

        row[
            "Donor_Selection_Check"
        ] = "PASS"

    elif len(qualifying) > 2:

        row[
            "Donor_Selection_Check"
        ] = (
            "CHECK_MULTIPLE_QUALIFYING_DONORS"
        )

    elif len(qualifying) == 1:

        row[
            "Donor_Selection_Check"
        ] = "ONLY_ONE_QUALIFYING_DONOR"

    else:

        row[
            "Donor_Selection_Check"
        ] = "NO_QUALIFYING_DONORS"


    # ========================================================
    # PALLADACYCLE
    # ========================================================

    palladacycle = (
        determine_palladacycle(
            ligand_name,
            elements,
            coordinates,
            donor1,
            donor2
        )
    )

    row.update(
        palladacycle
    )


    # ========================================================
    # STERIC
    # ========================================================

    steric = calculate_steric(
        elements,
        coordinates,
        donor1
    )

    row.update(
        steric
    )


    # ========================================================
    # COORDINATION
    # ========================================================

    coordination = (
        calculate_coordination(
            elements,
            coordinates,
            donor1,
            donor2
        )
    )

    row.update(
        coordination
    )


    # ========================================================
    # PYRAMIDALIZATION
    # ========================================================

    pyr = calculate_pyramidalization(
        elements,
        coordinates,
        donor1,
        donor2
    )

    row.update(
        pyr
    )


    # ========================================================
    # xTB
    # ========================================================

    xtb = calculate_xtb(
        elements,
        coordinates,
        donor1,
        donor2
    )

    row.update(
        xtb
    )


    # ========================================================
    # NBO
    # ========================================================

    nbo_defaults = {

        "NBO_Donor1_to_Pd_E2_kcal":
            np.nan,

        "NBO_Donor2_to_Pd_E2_kcal":
            np.nan,

        "NBO_Total_Ligand_to_Pd_E2_kcal":
            np.nan,

        "NBO_Max_Ligand_to_Pd_E2_kcal":
            np.nan,

        "NBO_Donor_Orbital_Gap_eV":
            np.nan
    }

    row.update(
        nbo_defaults
    )


    if len(nbo_table) > 0:

        match = nbo_table[
            nbo_table["Ligand_ID"]
            ==
            ligand_name
        ]

        if len(match) == 1:

            for col in nbo_defaults:

                if col in match.columns:

                    row[col] = finite(
                        match.iloc[0][col]
                    )


    # ========================================================
    # YIELD
    # ========================================================

    row[
        "Yield"
    ] = YIELD_DATA.get(
        ligand_name,
        np.nan
    )


    # ========================================================
    # WARNINGS
    # ========================================================

    warnings_list = []


    if row[
        "Donor_Selection_Check"
    ] != "PASS":

        warnings_list.append(
            row[
                "Donor_Selection_Check"
            ]
        )


    if (
        row[
            "Palladacycle_Type_Check"
        ]
        ==
        "CHECK"
    ):

        warnings_list.append(
            "Palladacycle type mismatch."
        )


    if pd.isna(
        row.get(
            "Bite_Angle_deg",
            np.nan
        )
    ):

        warnings_list.append(
            "Bite angle unavailable."
        )


    if pd.isna(
        row.get(
            "XTB_HOMO_eV",
            np.nan
        )
    ):

        warnings_list.append(
            "xTB descriptors unavailable."
        )


    if NBO_TABLE_FILE is None:

        warnings_list.append(
            "NBO table not supplied."
        )


    row[
        "Warnings"
    ] = " || ".join(
        warnings_list
    )


    row[
        "Overall_Status"
    ] = (
        "PASS"
        if len(warnings_list) == 0
        else "WARNING"
    )


    return row


# ============================================================
# 23. PROCESS ALL XYZ
# ============================================================

print("\n")
print("=" * 80)
print("PROCESSING XYZ FILES")
print("=" * 80)


all_rows = []


for i, filepath in enumerate(
    xyz_files,
    start=1
):

    print(
        f"\n[{i}/{len(xyz_files)}] "
        f"{os.path.basename(filepath)}"
    )

    try:

        row = process_xyz(
            filepath
        )

        all_rows.append(
            row
        )

        print(
            "  Ligand:",
            row["Ligand"]
        )

        print(
            "  Donor 1:",
            row.get(
                "Donor1_Atom"
            ),
            row.get(
                "Donor1_Element"
            ),
            row.get(
                "Pd_Donor1_Distance_A"
            )
        )

        print(
            "  Donor 2:",
            row.get(
                "Donor2_Atom"
            ),
            row.get(
                "Donor2_Element"
            ),
            row.get(
                "Pd_Donor2_Distance_A"
            )
        )

        print(
            "  Palladacycle:",
            row.get(
                "Palladacycle_Type"
            )
        )

        print(
            "  Yield:",
            row.get(
                "Yield"
            )
        )

    except Exception as e:

        print(
            "  ERROR:",
            e
        )

        all_rows.append({

            "Ligand":
                clean_ligand_name(filepath),

            "XYZ_File":
                os.path.basename(filepath),

            "Overall_Status":
                "ERROR",

            "Warnings":
                str(e),

            "Yield":
                YIELD_DATA.get(
                    clean_ligand_name(filepath),
                    np.nan
                )
        })


# ============================================================
# 24. MASTER DATAFRAME
# ============================================================

master_df = pd.DataFrame(
    all_rows
)


# ============================================================
# 25. SORT L7 -> L25
# ============================================================

def ligand_sort_number(x):

    match = re.search(
        r"L(\d+)",
        str(x)
    )

    if match:
        return int(
            match.group(1)
        )

    return 9999


master_df[
    "_Sort"
] = master_df[
    "Ligand"
].apply(
    ligand_sort_number
)

master_df = (
    master_df
    .sort_values("_Sort")
    .drop(
        columns="_Sort"
    )
    .reset_index(
        drop=True
    )
)


# ============================================================
# 26. VERIFY YIELD MATCHING
# ============================================================

print("\n")
print("=" * 80)
print("YIELD MATCHING")
print("=" * 80)

yield_check = master_df[
    [
        "Ligand",
        "Yield"
    ]
]

print(
    yield_check.to_string(
        index=False
    )
)

print(
    "\nTotal ligands:",
    len(master_df)
)

print(
    "Yield available:",
    master_df[
        "Yield"
    ].notna().sum()
)

print(
    "Yield missing:",
    master_df[
        "Yield"
    ].isna().sum()
)


# ============================================================
# 27. DESCRIPTOR CATEGORIES
# ============================================================

steric_cols = [
    c for c in master_df.columns
    if (
        c.startswith("Ligand_SASA")
        or
        c.startswith("Ligand_%Vbur")
        or
        c.startswith("Ligand_Solid")
        or
        c.startswith("Ligand_Maximum")
        or
        c.startswith("Pd_Oriented_Sterimol")
    )
]


coord_cols = [
    c for c in master_df.columns
    if (
        c.startswith("Pd_Donor")
        or
        c.startswith("Average_Pd")
        or
        c.startswith("Delta_Pd")
        or
        c.startswith("Donor1_Donor2")
        or
        c.startswith("Bite_Angle")
        or
        c.startswith("Pd_Coordination")
        or
        c.startswith("Palladacycle_")
    )
]


donor_cols = [
    c for c in master_df.columns
    if (
        "Donor1_Mulliken" in c
        or
        "Donor2_Mulliken" in c
        or
        "Average_Donor_Charge" in c
        or
        "Delta_Donor_Charge" in c
        or
        "Donor_Charge_Sum" in c
    )
]


pyr_cols = [
    c for c in master_df.columns
    if (
        "Pyramidalization" in c
    )
]


xtb_cols = [
    c for c in master_df.columns
    if c.startswith("XTB_")
]


nbo_cols = [
    c for c in master_df.columns
    if c.startswith("NBO_")
]


print("\nDescriptor counts:")

print(
    "A Steric:",
    len(steric_cols)
)

print(
    "B Coordination:",
    len(coord_cols)
)

print(
    "C Donor electronic:",
    len(donor_cols)
)

print(
    "D Pyramidalization:",
    len(pyr_cols)
)

print(
    "E xTB:",
    len(xtb_cols)
)

print(
    "F NBO:",
    len(nbo_cols)
)


# ============================================================
# 28. NUMERIC DATASET
# ============================================================

numeric_df = master_df.select_dtypes(
    include=[np.number]
).copy()


# ============================================================
# 29. REMOVE NON-PREDICTOR / QC VARIABLES
#
# These stay in ALL_DESCRIPTORS but are NOT predictors.
# ============================================================

EXCLUDE_FROM_CORRELATION = {

    "Pd_Atom",

    "Ligand_Start_Atom",

    "Pd_Donor_Min_A",

    "Pd_Donor_Max_A",

    "Donor1_Atom",

    "Donor2_Atom",

    "N_Atoms",

    "Number_of_Donor_Candidates",

    "Number_of_Qualifying_Pd_Donors",

    # Pyramidalization QC
    "Donor1_Pyramidalization_Neighbor_Count",

    "Donor2_Pyramidalization_Neighbor_Count",

    # Metadata / settings
    "XTB_Charge",
    "XTB_N_Unpaired",
    "XTB_Method"
}


numeric_df = numeric_df.drop(
    columns=[
        c
        for c in EXCLUDE_FROM_CORRELATION
        if c in numeric_df.columns
    ],
    errors="ignore"
)


# ============================================================
# 30. REMOVE CONSTANT DESCRIPTORS
# ============================================================

constant_columns = []

for col in numeric_df.columns:

    if col == "Yield":
        continue

    values = numeric_df[
        col
    ].dropna()

    if values.nunique() <= 1:

        constant_columns.append(
            col
        )


numeric_df = numeric_df.drop(
    columns=constant_columns,
    errors="ignore"
)


print("\nConstant descriptors removed:")

if constant_columns:

    for c in constant_columns:
        print(" ",
              c)

else:

    print("  None")


# ============================================================
# 31. REQUIRE COMPLETE DESCRIPTORS
#
# We do NOT impute missing descriptor values.
# ============================================================

complete_columns = []

missing_columns = []

for col in numeric_df.columns:

    if numeric_df[
        col
    ].notna().all():

        complete_columns.append(
            col
        )

    else:

        missing_columns.append(
            col
        )


# Yield must remain
if "Yield" not in complete_columns:

    raise ValueError(
        "Yield contains missing values."
    )


correlation_base = numeric_df[
    complete_columns
].copy()


# ============================================================
# 32. OUTLIER SCREENING
#
# Descriptor removed if >10% observations are outliers
# by either IQR or MAD criterion.
#
# With 19 ligands:
# 2 or more outliers => >10%
# ============================================================

outlier_records = []

excluded_outliers = []

retained = []


descriptor_columns = [
    c
    for c in correlation_base.columns
    if c != "Yield"
]


for col in descriptor_columns:

    x = correlation_base[
        col
    ].dropna().astype(float)

    n = len(x)


    # --------------------------------------------------------
    # IQR
    # --------------------------------------------------------

    q1 = x.quantile(
        0.25
    )

    q3 = x.quantile(
        0.75
    )

    iqr = q3 - q1

    if iqr > 0:

        lower = (
            q1
            -
            IQR_MULTIPLIER * iqr
        )

        upper = (
            q3
            +
            IQR_MULTIPLIER * iqr
        )

        iqr_mask = (
            (x < lower)
            |
            (x > upper)
        )

        n_iqr = int(
            iqr_mask.sum()
        )

    else:

        n_iqr = 0


    # --------------------------------------------------------
    # MAD
    # --------------------------------------------------------

    median = x.median()

    mad = np.median(
        np.abs(
            x - median
        )
    )

    if mad > 0:

        modified_z = (
            0.6745
            *
            (x - median)
            /
            mad
        )

        mad_mask = (
            np.abs(
                modified_z
            )
            >
            MAD_Z_LIMIT
        )

        n_mad = int(
            mad_mask.sum()
        )

    else:

        n_mad = 0


    iqr_fraction = (
        n_iqr / n
        if n > 0
        else np.nan
    )

    mad_fraction = (
        n_mad / n
        if n > 0
        else np.nan
    )


    remove = (
        iqr_fraction
        >
        OUTLIER_FRACTION_LIMIT
        or
        mad_fraction
        >
        OUTLIER_FRACTION_LIMIT
    )


    outlier_records.append({

        "Descriptor":
            col,

        "N":
            n,

        "IQR_Outliers":
            n_iqr,

        "IQR_Outlier_Fraction":
            iqr_fraction,

        "MAD_Outliers":
            n_mad,

        "MAD_Outlier_Fraction":
            mad_fraction,

        "Removed":
            remove
    })


    if remove:

        excluded_outliers.append(
            col
        )

    else:

        retained.append(
            col
        )


outlier_df = pd.DataFrame(
    outlier_records
)


# ============================================================
# 33. FINAL FILTERED CORRELATION DATA
# ============================================================

correlation_columns = [
    "Yield"
] + retained


correlation_df = correlation_base[
    correlation_columns
].copy()


print("\n" + "=" * 80)
print("CORRELATION DATASET")
print("=" * 80)

print(
    "Yield + retained descriptors:",
    correlation_df.shape
)

print(
    "\nRetained descriptors:",
    len(retained)
)

print(
    "Removed due to excessive outliers:",
    len(excluded_outliers)
)


if excluded_outliers:

    print("\nRemoved:")

    for c in excluded_outliers:
        print(
            " ",
            c
        )


# ============================================================
# 34. FULL SQUARE PEARSON
# ============================================================

pearson_matrix_full = (
    correlation_df.corr(
        method="pearson"
    )
)


# ============================================================
# 35. FULL SQUARE SPEARMAN
# ============================================================

spearman_matrix_full = (
    correlation_df.corr(
        method="spearman"
    )
)


print(
    "\nFull Pearson matrix:",
    pearson_matrix_full.shape
)

print(
    "Full Spearman matrix:",
    spearman_matrix_full.shape
)


# ============================================================
# 36. ALSO CREATE RAW COMPLETE-DESCRIPTOR MATRICES
#
# Before outlier filtering
# ============================================================

raw_correlation_columns = [
    "Yield"
] + [
    c
    for c in correlation_base.columns
    if c != "Yield"
]

raw_correlation_df = correlation_base[
    raw_correlation_columns
].copy()


pearson_matrix_raw = (
    raw_correlation_df.corr(
        method="pearson"
    )
)


spearman_matrix_raw = (
    raw_correlation_df.corr(
        method="spearman"
    )
)


# ============================================================
# 37–38. PUBLICATION-QUALITY CORRELATION MATRICES
# ============================================================

MATRIX_ANNOTATION_MAX = 30
MATRIX_DPI = 600
MATRIX_BASE_FONT = 10
MATRIX_TICK_FONT = 9
MATRIX_TITLE_FONT = 16


def plot_correlation_matrix(matrix, title, colorbar_label, outfile):

    n = len(matrix)
    side = max(16, min(32, n * 0.68))
    annotation_font = max(8, min(14, 260 / max(n, 1)))

    fig, ax = plt.subplots(figsize=(side, side), constrained_layout=True)

    sns.heatmap(
        matrix,
        ax=ax,
        cmap="RdBu_r",
        center=0,
        vmin=-1,
        vmax=1,
        square=True,
        linewidths=0.35,
        linecolor="white",
        annot=(n <= MATRIX_ANNOTATION_MAX),
        fmt=".2f",
        annot_kws={
            "fontsize": annotation_font,
            "fontweight": "normal"
        },
        cbar_kws={
            "label": colorbar_label,
            "shrink": 0.78,
            "pad": 0.02
        }
    )

    ax.set_title(title, fontsize=MATRIX_TITLE_FONT, pad=16, weight="bold")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="center", fontsize=MATRIX_TICK_FONT)
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=MATRIX_TICK_FONT)
    ax.tick_params(length=0)

    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=9)
    cbar.set_label(colorbar_label, fontsize=10)

    fig.savefig(outfile, dpi=MATRIX_DPI, bbox_inches="tight", facecolor="white")
    plt.show()
    plt.close(fig)


plot_correlation_matrix(
    pearson_matrix_full,
    "Pearson Correlation Matrix\nYield + Retained Ligand Descriptors",
    "Pearson r",
    os.path.join(PLOT_FOLDER, "Pearson_FULL_SQUARE_Correlation_Matrix.png")
)

plot_correlation_matrix(
    spearman_matrix_full,
    "Spearman Correlation Matrix\nYield + Retained Ligand Descriptors",
    "Spearman ρ",
    os.path.join(PLOT_FOLDER, "Spearman_FULL_SQUARE_Correlation_Matrix.png")
)


# ============================================================
# 39. YIELD CORRELATIONS
# ============================================================

correlation_results = []


for descriptor in retained:

    temp = correlation_df[
        [
            "Yield",
            descriptor
        ]
    ].dropna()

    n = len(temp)


    if n >= 3:

        try:

            r, p_r = pearsonr(
                temp["Yield"],
                temp[descriptor]
            )

        except Exception:

            r = np.nan
            p_r = np.nan

        try:

            rho, p_s = spearmanr(
                temp["Yield"],
                temp[descriptor]
            )

        except Exception:

            rho = np.nan
            p_s = np.nan

    else:

        r = np.nan
        p_r = np.nan

        rho = np.nan
        p_s = np.nan


    correlation_results.append({

        "Descriptor":
            descriptor,

        "N":
            n,

        "Pearson_r":
            r,

        "Pearson_p":
            p_r,

        "Spearman_rho":
            rho,

        "Spearman_p":
            p_s,

        "Abs_Pearson_r":
            abs(r)
            if pd.notna(r)
            else np.nan,

        "Abs_Spearman_rho":
            abs(rho)
            if pd.notna(rho)
            else np.nan
    })


yield_correlation_df = pd.DataFrame(
    correlation_results
)


yield_correlation_df[
    "Mean_Abs_Correlation"
] = (
    yield_correlation_df[
        "Abs_Pearson_r"
    ]
    +
    yield_correlation_df[
        "Abs_Spearman_rho"
    ]
) / 2.0


yield_correlation_df = (
    yield_correlation_df
    .sort_values(
        "Mean_Abs_Correlation",
        ascending=False
    )
    .reset_index(
        drop=True
    )
)


# ============================================================
# 40. PRINT YIELD CORRELATIONS
# ============================================================

print("\n")
print("=" * 100)
print("YIELD vs RETAINED DESCRIPTORS")
print("=" * 100)

display(
    yield_correlation_df
)


# ============================================================
# 41. PEARSON YIELD RANKING
# ============================================================

pearson_rank = (
    yield_correlation_df
    .sort_values(
        "Pearson_r",
        ascending=True
    )
)


plt.figure(
    figsize=(
        10,
        max(
            6,
            len(pearson_rank)
            * 0.32
        )
    )
)


plt.barh(
    pearson_rank[
        "Descriptor"
    ],
    pearson_rank[
        "Pearson_r"
    ]
)


plt.axvline(
    0,
    linewidth=1
)

plt.xlabel(
    "Pearson r"
)

plt.ylabel(
    "Descriptor"
)

plt.title(
    "Pearson Correlation with Yield"
)

plt.tight_layout()


plt.savefig(
    os.path.join(
        PLOT_FOLDER,
        "Pearson_Yield_Correlation_Ranking.png"
    ),
    dpi=400,
    bbox_inches="tight"
)

plt.show()

plt.close()


# ============================================================
# 42. SPEARMAN YIELD RANKING
# ============================================================

spearman_rank = (
    yield_correlation_df
    .sort_values(
        "Spearman_rho",
        ascending=True
    )
)


plt.figure(
    figsize=(
        10,
        max(
            6,
            len(spearman_rank)
            * 0.32
        )
    )
)


plt.barh(
    spearman_rank[
        "Descriptor"
    ],
    spearman_rank[
        "Spearman_rho"
    ]
)


plt.axvline(
    0,
    linewidth=1
)

plt.xlabel(
    "Spearman ρ"
)

plt.ylabel(
    "Descriptor"
)

plt.title(
    "Spearman Correlation with Yield"
)

plt.tight_layout()


plt.savefig(
    os.path.join(
        PLOT_FOLDER,
        "Spearman_Yield_Correlation_Ranking.png"
    ),
    dpi=400,
    bbox_inches="tight"
)

plt.show()

plt.close()


# ============================================================
# 43. PEARSON vs SPEARMAN
# ============================================================

plt.figure(
    figsize=(8, 8)
)


plt.scatter(
    yield_correlation_df[
        "Pearson_r"
    ],
    yield_correlation_df[
        "Spearman_rho"
    ],
    s=65,
    alpha=0.85
)


for _, row in (
    yield_correlation_df.iterrows()
):

    if (
        pd.notna(
            row["Pearson_r"]
        )
        and
        pd.notna(
            row["Spearman_rho"]
        )
    ):

        plt.annotate(
            row["Descriptor"],
            (
                row["Pearson_r"],
                row["Spearman_rho"]
            ),
            xytext=(4, 4),
            textcoords="offset points",
            fontsize=7
        )


plt.axhline(
    0,
    linewidth=1
)

plt.axvline(
    0,
    linewidth=1
)

plt.xlabel(
    "Pearson r"
)

plt.ylabel(
    "Spearman ρ"
)

plt.title(
    "Pearson vs Spearman Correlation with Yield"
)

plt.grid(
    alpha=0.25
)

plt.tight_layout()


plt.savefig(
    os.path.join(
        PLOT_FOLDER,
        "Pearson_vs_Spearman_Yield.png"
    ),
    dpi=400,
    bbox_inches="tight"
)

plt.show()

plt.close()


# ============================================================
# 44. YIELD vs EVERY DESCRIPTOR
#
# IMPORTANT:
# NO REGRESSION LINE
# ============================================================

for descriptor in retained:

    temp = correlation_df[
        [
            "Yield",
            descriptor
        ]
    ].dropna()

    if len(temp) < 3:
        continue


    try:

        r, p_r = pearsonr(
            temp[descriptor],
            temp["Yield"]
        )

    except Exception:

        r = np.nan
        p_r = np.nan


    try:

        rho, p_s = spearmanr(
            temp[descriptor],
            temp["Yield"]
        )

    except Exception:

        rho = np.nan
        p_s = np.nan


    plt.figure(
        figsize=(7, 5)
    )


    plt.scatter(
        temp[descriptor],
        temp["Yield"],
        s=55,
        alpha=0.85
    )


    # --------------------------------------------------------
    # Ligand labels
    # --------------------------------------------------------

    for idx in temp.index:

        label = master_df.loc[
            idx,
            "Ligand"
        ]

        if pd.notna(label):

            plt.annotate(
                str(label),
                (
                    temp.loc[
                        idx,
                        descriptor
                    ],
                    temp.loc[
                        idx,
                        "Yield"
                    ]
                ),
                xytext=(4, 4),
                textcoords="offset points",
                fontsize=7
            )


    plt.xlabel(
        descriptor
    )

    plt.ylabel(
        "Yield (%)"
    )

    plt.title(
        f"Yield vs {descriptor}"
    )


    stats_text = (
        f"Pearson r = {r:.3f}\n"
        f"Pearson p = {p_r:.3g}\n"
        f"Spearman ρ = {rho:.3f}\n"
        f"Spearman p = {p_s:.3g}\n"
        f"n = {len(temp)}"
    )


    plt.text(
        0.03,
        0.97,
        stats_text,
        transform=plt.gca().transAxes,
        va="top",
        fontsize=9,
        bbox=dict(
            boxstyle="round",
            alpha=0.15
        )
    )


    plt.grid(
        alpha=0.25
    )

    plt.tight_layout()


    outfile = os.path.join(
        SCATTER_FOLDER,
        "Yield_vs_"
        +
        safe_filename(
            descriptor
        )
        +
        ".png"
    )


    plt.savefig(
        outfile,
        dpi=400,
        bbox_inches="tight"
    )

    plt.close()


# ============================================================
# 45. DESCRIPTOR BOXPLOTS
# ============================================================

for descriptor in retained:

    values = correlation_df[
        descriptor
    ].dropna()

    if len(values) < 3:
        continue


    plt.figure(
        figsize=(6, 4)
    )


    plt.boxplot(
        values
    )

    plt.ylabel(
        descriptor
    )

    plt.title(
        f"Distribution: {descriptor}"
    )

    plt.grid(
        axis="y",
        alpha=0.25
    )

    plt.tight_layout()


    outfile = os.path.join(
        BOX_FOLDER,
        "Boxplot_"
        +
        safe_filename(
            descriptor
        )
        +
        ".png"
    )


    plt.savefig(
        outfile,
        dpi=350,
        bbox_inches="tight"
    )

    plt.close()


# ============================================================
# 46. HIGH CORRELATION BETWEEN DESCRIPTORS
# ============================================================

high_pairs = []


for i in range(
    len(retained)
):

    for j in range(
        i + 1,
        len(retained)
    ):

        d1 = retained[i]
        d2 = retained[j]


        r = pearson_matrix_full.loc[
            d1,
            d2
        ]

        rho = spearman_matrix_full.loc[
            d1,
            d2
        ]

        if (
            abs(r)
            >=
            HIGH_CORR_THRESHOLD
            or
            abs(rho)
            >=
            HIGH_CORR_THRESHOLD
        ):

            high_pairs.append({

                "Descriptor_1":
                    d1,

                "Descriptor_2":
                    d2,

                "Pearson_r":
                    r,

                "Spearman_rho":
                    rho,

                "Max_Abs_Correlation":
                    max(
                        abs(r),
                        abs(rho)
                    )
            })


high_corr_df = pd.DataFrame(
    high_pairs
)


if len(high_corr_df) > 0:

    high_corr_df = (
        high_corr_df
        .sort_values(
            "Max_Abs_Correlation",
            ascending=False
        )
        .reset_index(
            drop=True
        )
    )


# ============================================================
# 47. YIELD BY PALLADACYCLE TYPE
# ============================================================

class_df = master_df[
    [
        "Palladacycle_Type",
        "Yield"
    ]
].dropna()


if len(class_df) > 0:

    plt.figure(
        figsize=(7, 5)
    )


    sns.boxplot(
        data=class_df,
        x="Palladacycle_Type",
        y="Yield"
    )


    sns.stripplot(
        data=class_df,
        x="Palladacycle_Type",
        y="Yield",
        jitter=True,
        alpha=0.7
    )


    plt.xlabel(
        "Palladacycle type"
    )

    plt.ylabel(
        "Yield (%)"
    )

    plt.title(
        "Yield by Palladacycle Type"
    )

    plt.tight_layout()


    plt.savefig(
        os.path.join(
            PLOT_FOLDER,
            "Yield_by_Palladacycle_Type.png"
        ),
        dpi=400,
        bbox_inches="tight"
    )

    plt.show()

    plt.close()


# ============================================================
# 48. SAVE VALIDATION TABLE
# ============================================================

validation_columns = [

    "Ligand",

    "XYZ_File",

    "N_Atoms",

    "Donor1_Atom",
    "Donor1_Element",

    "Donor2_Atom",
    "Donor2_Element",

    "Pd_Donor1_Distance_A",
    "Pd_Donor2_Distance_A",

    "Number_of_Qualifying_Pd_Donors",

    "Donor_Selection_Check",

    "Palladacycle_Type",

    "Expected_Palladacycle_Type",

    "Palladacycle_Type_Check",

    "Palladacycle_Ligand_Path",

    "Overall_Status",

    "Warnings"
]


validation_columns = [
    c
    for c in validation_columns
    if c in master_df.columns
]


validation_df = master_df[
    validation_columns
].copy()


# ============================================================
# 49. FINAL EXCEL WORKBOOK
# ============================================================

print("\n")
print("=" * 80)
print("WRITING FINAL EXCEL WORKBOOK")
print("=" * 80)


with pd.ExcelWriter(
    FINAL_EXCEL,
    engine="openpyxl"
) as writer:


    # --------------------------------------------------------
    # COMPLETE RAW DATA
    # --------------------------------------------------------

    master_df.to_excel(
        writer,
        sheet_name="ALL_DESCRIPTORS",
        index=False
    )


    # --------------------------------------------------------
    # VALIDATION
    # --------------------------------------------------------

    validation_df.to_excel(
        writer,
        sheet_name="VALIDATION",
        index=False
    )


    # --------------------------------------------------------
    # YIELD CORRELATION DATA
    # --------------------------------------------------------

    correlation_df.to_excel(
        writer,
        sheet_name="Correlation_Data",
        index=False
    )


    # --------------------------------------------------------
    # FULL RAW PEARSON
    # --------------------------------------------------------

    pearson_matrix_raw.to_excel(
        writer,
        sheet_name="Pearson_RAW_FULL"
    )


    # --------------------------------------------------------
    # FULL RAW SPEARMAN
    # --------------------------------------------------------

    spearman_matrix_raw.to_excel(
        writer,
        sheet_name="Spearman_RAW_FULL"
    )


    # --------------------------------------------------------
    # FILTERED PEARSON
    # --------------------------------------------------------

    pearson_matrix_full.to_excel(
        writer,
        sheet_name="Pearson_FILTERED_FULL"
    )


    # --------------------------------------------------------
    # FILTERED SPEARMAN
    # --------------------------------------------------------

    spearman_matrix_full.to_excel(
        writer,
        sheet_name="Spearman_FILTERED_FULL"
    )


    # --------------------------------------------------------
    # YIELD CORRELATIONS
    # --------------------------------------------------------

    yield_correlation_df.to_excel(
        writer,
        sheet_name="Yield_Correlations",
        index=False
    )


    # --------------------------------------------------------
    # OUTLIER SCREENING
    # --------------------------------------------------------

    outlier_df.to_excel(
        writer,
        sheet_name="Outlier_Screening",
        index=False
    )


    # --------------------------------------------------------
    # HIGH CORRELATION PAIRS
    # --------------------------------------------------------

    high_corr_df.to_excel(
        writer,
        sheet_name="High_Correlation_Pairs",
        index=False
    )


    # --------------------------------------------------------
    # A - STERIC
    # --------------------------------------------------------

    cols = [
        "Ligand"
    ] + [
        c for c in steric_cols
        if c in master_df.columns
    ] + ["Yield"]

    master_df[
        list(dict.fromkeys(cols))
    ].to_excel(
        writer,
        sheet_name="A_STERIC",
        index=False
    )


    # --------------------------------------------------------
    # B - COORDINATION
    # --------------------------------------------------------

    cols = [
        "Ligand"
    ] + [
        c for c in coord_cols
        if c in master_df.columns
    ] + ["Yield"]

    master_df[
        list(dict.fromkeys(cols))
    ].to_excel(
        writer,
        sheet_name="B_COORDINATION",
        index=False
    )


    # --------------------------------------------------------
    # C - DONOR ELECTRONIC
    # --------------------------------------------------------

    cols = [
        "Ligand"
    ] + [
        c for c in donor_cols
        if c in master_df.columns
    ] + ["Yield"]

    master_df[
        list(dict.fromkeys(cols))
    ].to_excel(
        writer,
        sheet_name="C_DONOR_ELECTRONIC",
        index=False
    )


    # --------------------------------------------------------
    # D - PYRAMIDALIZATION
    # --------------------------------------------------------

    cols = [
        "Ligand"
    ] + [
        c for c in pyr_cols
        if c in master_df.columns
    ] + ["Yield"]

    master_df[
        list(dict.fromkeys(cols))
    ].to_excel(
        writer,
        sheet_name="D_PYRAMIDALIZATION",
        index=False
    )


    # --------------------------------------------------------
    # E - xTB
    # --------------------------------------------------------

    cols = [
        "Ligand"
    ] + [
        c for c in xtb_cols
        if c in master_df.columns
    ] + ["Yield"]

    master_df[
        list(dict.fromkeys(cols))
    ].to_excel(
        writer,
        sheet_name="E_XTB",
        index=False
    )


    # --------------------------------------------------------
    # F - NBO
    # --------------------------------------------------------

    cols = [
        "Ligand"
    ] + [
        c for c in nbo_cols
        if c in master_df.columns
    ] + ["Yield"]

    master_df[
        list(dict.fromkeys(cols))
    ].to_excel(
        writer,
        sheet_name="F_NBO",
        index=False
    )


    # --------------------------------------------------------
    # YIELD DATA
    # --------------------------------------------------------

    yield_table = pd.DataFrame({

        "Ligand":
            list(YIELD_DATA.keys()),

        "Yield":
            list(YIELD_DATA.values())
    })


    yield_table.to_excel(
        writer,
        sheet_name="YIELD_DATA",
        index=False
    )


    # --------------------------------------------------------
    # REMOVED DESCRIPTORS
    # --------------------------------------------------------

    removed_records = []

    for c in constant_columns:

        removed_records.append({

            "Descriptor":
                c,

            "Reason":
                "Constant descriptor"
        })

    for c in missing_columns:

        if c != "Yield":

            removed_records.append({

                "Descriptor":
                    c,

                "Reason":
                    "Contains missing value(s)"
            })

    for c in excluded_outliers:

        removed_records.append({

            "Descriptor":
                c,

            "Reason":
                "More than 10% strong outliers"
        })

    removed_df = pd.DataFrame(
        removed_records
    )

    removed_df.to_excel(
        writer,
        sheet_name="REMOVED_DESCRIPTORS",
        index=False
    )


# ============================================================
# 50. FINAL SUMMARY
# ============================================================

print("\n")
print("=" * 100)
print("FINAL ANALYSIS COMPLETE")
print("=" * 100)

print(
    "\nExcel:"
)

print(
    FINAL_EXCEL
)

print(
    "\nPlots:"
)

print(
    PLOT_FOLDER
)

print(
    "\nNumber of ligands:",
    len(master_df)
)

print(
    "Total descriptors in raw table:",
    len(
        [
            c for c in master_df.columns
            if c not in [
                "Ligand",
                "XYZ_File",
                "Warnings",
                "Overall_Status"
            ]
        ]
    )
)

print(
    "Retained correlation descriptors:",
    len(retained)
)

print(
    "Constant removed:",
    len(constant_columns)
)

print(
    "Missing-value removed:",
    len(
        [
            c
            for c in missing_columns
            if c != "Yield"
        ]
    )
)

print(
    "Outlier removed:",
    len(excluded_outliers)
)

print(
    "\nPearson matrix:",
    pearson_matrix_full.shape
)

print(
    "Spearman matrix:",
    spearman_matrix_full.shape
)

print(
    "\nTop 10 Yield correlations:"
)

display(
    yield_correlation_df.head(10)
)

print(
    "\n" + "=" * 100
)
print(
    "✓ ALL PROCESSING FINISHED"
)
print(
    "=" * 100
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ================================================================================
# CHECKING xTB
# ================================================================================
#
# ================================================================================
# xTB VERIFICATION
# ================================================================================
# xTB executable: /content/xtb-dist/bin/xtb
#       -----------------------------------------------------------
#      |                   =====================                   |
#      |                           x T B                           |
#      |                   =====================                   |
#      |                         S. Grimme                         |
#      |          Mulliken Center for Theoretical Chemistry        |
#      |                    University of Bonn                     |
#       -----------------------------------------------------------
#
#    * xtb version 6.7.1 (edcfbbe) compiled by 'albert@albert-system' on 2024-07-22
#
#
# ================================================================================
# ✓ xTB READY
# ================================================================================
#
# ================================================================================
# XYZ FILES
# ================================================================================
# Found 19 XYZ files.
#   L10_new.xyz
#   L11_new.xyz
#   L12_new.xyz
#   L13_new.xyz
#   L14-new.xyz
#   L15_new.xyz
#   L16_new.xyz
#   L17_new.xyz
#   L18_new.xyz
#   L19_new.xyz
#   L20_new.xyz
#   L21-new.xyz
#   L22_new.xyz
#   L23_new.xyz
#   L24_new.xyz
#   L25_new.xyz
#   L7_new.xyz
#   L8_new.xyz
#   L9_new.xyz
#
#
# ================================================================================
# PROCESSING XYZ FILES
# ================================================================================
#
# [1/19] L10_new.xyz
#   Ligand: L10
#   Donor 1: 17 N 2.112539265549637
#   Donor 2: 20 N 2.1270163421478454
#   Palladacycle: 4-membered
#   Yield: 0
#
# [2/19] L11_new.xyz
#   Ligand: L11
#   Donor 1: 20 N 2.136284747195701
#   Donor 2: 17 N 2.1486572303171116
#   Palladacycle: 4-membered
#   Yield: 0
#
# [3/19] L12_new.xyz
#   Ligand: L12
#   Donor 1: 17 N 2.121125260667319
#   Donor 2: 20 N 2.2855310735330203
#   Palladacycle: 4-membered
#   Yield: 0
#
# [4/19] L13_new.xyz
#   Ligand: L13
#   Donor 1: 17 N 2.1082510928293146
#   Donor 2: 20 N 2.138894520627186
#   Palladacycle: 4-membered
#   Yield: 0
#
# [5/19] L14-new.xyz
#   Ligand: L14
#   Donor 1: 17 N 2.1391236666480973
#   Donor 2: 20 N 2.164505380044365
#   Palladacycle: 4-membered
#   Yield: 0
#
# [6/19] L15_new.xyz
#   Ligand: L15
#   Donor 1: 17 N 2.1389644943789974
#   Donor 2: 20 N 2.1770916512600014
#   Palladacycle: 4-membered
#   Yield: 0
#
# [7/19] L16_new.xyz
#   Ligand: L16
#   Donor 1: 17 N 2.1064700144208084
#   Donor 2: 21 N 2.206978262473829
#   Palladacycle: 5-membered
#   Yield: 12
#
# [8/19] L17_new.xyz
#   Ligand: L17
#   Donor 1: 17 N 2.0765219191065625
#   Donor 2: 21 N 2.2248838985171786
#   Palladacycle: 5-membered
#   Yield: 53
#
# [9/19] L18_new.xyz
#   Ligand: L18
#   Donor 1: 17 N 2.07574336653595
#   Donor 2: 21 N 2.219360987024418
#   Palladacycle: 5-membered
#   Yield: 46
#
# [10/19] L19_new.xyz
#   Ligand: L19
#   Donor 1: 17 N 2.076942849367551
#   Donor 2: 21 N 2.2196858307807887
#   Palladacycle: 5-membered
#   Yield: 67
#
# [11/19] L20_new.xyz
#   Ligand: L20
#   Donor 1: 17 N 2.0855303300623564
#   Donor 2: 21 N 2.246577147791947
#   Palladacycle: 5-membered
#   Yield: 40
#
# [12/19] L21-new.xyz
#   Ligand: L21
#   Donor 1: 17 N 2.0875314031364893
#   Donor 2: 21 N 2.2666159918632007
#   Palladacycle: 5-membered
#   Yield: 31
#
# [13/19] L22_new.xyz
#   Ligand: L22
#   Donor 1: 17 N 2.092416511745929
#   Donor 2: 21 O 2.36931554248669
#   Palladacycle: 5-membered
#   Yield: 0
#
# [14/19] L23_new.xyz
#   Ligand: L23
#   Donor 1: 17 N 2.0895490456179777
#   Donor 2: 21 N 2.163729044758146
#   Palladacycle: 5-membered
#   Yield: 0
#
# [15/19] L24_new.xyz
#   Ligand: L24
#   Donor 1: 17 N 2.096926810932847
#   Donor 2: 21 N 2.1630524139377667
#   Palladacycle: 5-membered
#   Yield: 0
#
# [16/19] L25_new.xyz
#   Ligand: L25
#   Donor 1: 17 N 2.100219892985732
#   Donor 2: 21 N 2.223977105338542
#   Palladacycle: 5-membered
#   Yield: 0
#
# [17/19] L7_new.xyz
#   Ligand: L7
#   Donor 1: 17 N 2.119733481968665
#   Donor 2: 20 N 2.342635527611156
#   Palladacycle: 4-membered
#   Yield: 0
#
# [18/19] L8_new.xyz
#   Ligand: L8
#   Donor 1: 17 N 2.1356663205290287
#   Donor 2: 20 O 2.280459371877736
#   Palladacycle: 4-membered
#   Yield: 0
#
# [19/19] L9_new.xyz
#   Ligand: L9
#   Donor 1: 17 N 2.130042990628593
#   Donor 2: 20 N 2.247561680835701
#   Palladacycle: 4-membered
#   Yield: 0
#
#
# ================================================================================
# YIELD MATCHING
# ================================================================================
# Ligand  Yield
#     L7      0
#     L8      0
#     L9      0
#    L10      0
#    L11      0
#    L12      0
#    L13      0
#    L14      0
#    L15      0
#    L16     12
#    L17     53
#    L18     46
#    L19     67
#    L20     40
#    L21     31
#    L22      0
#    L23      0
#    L24      0
#    L25      0
#
# Total ligands: 19
# Yield available: 19
# Yield missing: 0
#
# Descriptor counts:
# A Steric: 12
# B Coordination: 18
# C Donor electronic: 0
# D Pyramidalization: 12
# E xTB: 1
# F NBO: 5
#
# Constant descriptors removed:
#   Donor1_Pyramidalization_P
#   Donor1_Pyramidalization_P_Angle_deg
#   Average_Pyramidalization_P
#   Delta_Pyramidalization_P
#   Average_Pyramidalization_Angle_deg
#   Delta_Pyramidalization_Angle_deg
#   NBO_Donor1_to_Pd_E2_kcal
#   NBO_Donor2_to_Pd_E2_kcal
#   NBO_Total_Ligand_to_Pd_E2_kcal
#   NBO_Max_Ligand_to_Pd_E2_kcal
#   NBO_Donor_Orbital_Gap_eV
#
# ================================================================================
# CORRELATION DATASET
# ================================================================================
# Yield + retained descriptors: (19, 15)
#
# Retained descriptors: 14
# Removed due to excessive outliers: 11
#
# Removed:
#   Palladacycle_Path_Bond_SD_A
#   Palladacycle_Path_Bond_CV
#   Ligand_Maximum_Extension_A
#   Ligand_SASA_A2
#   Ligand_Solid_Angle_sr
#   Ligand_Solid_Cone_Angle_deg
#   Ligand_Solid_G_percent
#   Ligand_%Vbur_4.0A
#   Pd_Oriented_Sterimol_B1_A
#   Pd_Oriented_Sterimol_B5_A
#   Pd_Oriented_Sterimol_L_A
#
# Full Pearson matrix: (15, 15)
# Full Spearman matrix: (15, 15)
# ====================================================================================================
# YIELD vs RETAINED DESCRIPTORS
# ====================================================================================================
#                        Descriptor   N  Pearson_r  Pearson_p  Spearman_rho  \
# 0            Pd_Donor1_Distance_A  19  -0.728209   0.000408     -0.757001
# 1          Palladacycle_Ring_Size  19   0.575878   0.009871      0.629801
# 2    Palladacycle_Path_Atom_Count  19   0.575878   0.009871      0.629801
# 3        Donor1_Donor2_Distance_A  19   0.557718   0.013095      0.589015
# 4                  Bite_Angle_deg  19   0.573648   0.010228      0.525223
# 5               Ligand_%Vbur_3.0A  19   0.383662   0.104895      0.503959
# 6           Ligand_SASA_Volume_A3  19   0.313902   0.190619      0.414650
# 7               Ligand_%Vbur_3.5A  19   0.304010   0.205730      0.412523
# 8         Pd_Donor_Distance_Ratio  19   0.305549   0.203328      0.393386
# 9       Delta_Pd_Donor_Distance_A  19   0.293772   0.222181      0.346605
# 10   Pd_Coordination_Distortion_A  19   0.293772   0.222181      0.346605
# 11  Palladacycle_Path_Bond_Mean_A  19   0.295641   0.219116      0.257295
# 12    Average_Pd_Donor_Distance_A  19  -0.162436   0.506429     -0.082930
# 13           Pd_Donor2_Distance_A  19   0.077863   0.751369      0.138217
#
#     Spearman_p  Abs_Pearson_r  Abs_Spearman_rho  Mean_Abs_Correlation
# 0     0.000175       0.728209          0.757001              0.742605
# 1     0.003854       0.575878          0.629801              0.602839
# 2     0.003854       0.575878          0.629801              0.602839
# 3     0.007966       0.557718          0.589015              0.573367
# 4     0.020932       0.573648          0.525223              0.549436
# 5     0.027804       0.383662          0.503959              0.443810
# 6     0.077534       0.313902          0.414650              0.364276
# 7     0.079222       0.304010          0.412523              0.358267
# 8     0.095656       0.305549          0.393386              0.349467
# 9     0.146012       0.293772          0.346605              0.320188
# 10    0.146012       0.293772          0.346605              0.320188
# 11    0.287591       0.295641          0.257295              0.276468
# 12    0.735721       0.162436          0.082930              0.122683
# 13    0.572556       0.077863          0.138217              0.108040
# ================================================================================
# WRITING FINAL EXCEL WORKBOOK
# ================================================================================
#
#
# ====================================================================================================
# FINAL ANALYSIS COMPLETE
# ====================================================================================================
#
# Excel:
# /content/drive/MyDrive/Pd_gamma_arylation_RESULTS/Pd_gamma_arylation_COMPLETE_ANALYSIS.xlsx
#
# Plots:
# /content/drive/MyDrive/Pd_gamma_arylation_RESULTS/PLOTS
#
# Number of ligands: 19
# Total descriptors in raw table: 60
# Retained correlation descriptors: 14
# Constant removed: 11
# Missing-value removed: 2
# Outlier removed: 11
#
# Pearson matrix: (15, 15)
# Spearman matrix: (15, 15)
#
# Top 10 Yield correlations:
#                      Descriptor   N  Pearson_r  Pearson_p  Spearman_rho  \
# 0          Pd_Donor1_Distance_A  19  -0.728209   0.000408     -0.757001
# 1        Palladacycle_Ring_Size  19   0.575878   0.009871      0.629801
# 2  Palladacycle_Path_Atom_Count  19   0.575878   0.009871      0.629801
# 3      Donor1_Donor2_Distance_A  19   0.557718   0.013095      0.589015
# 4                Bite_Angle_deg  19   0.573648   0.010228      0.525223
# 5             Ligand_%Vbur_3.0A  19   0.383662   0.104895      0.503959
# 6         Ligand_SASA_Volume_A3  19   0.313902   0.190619      0.414650
# 7             Ligand_%Vbur_3.5A  19   0.304010   0.205730      0.412523
# 8       Pd_Donor_Distance_Ratio  19   0.305549   0.203328      0.393386
# 9     Delta_Pd_Donor_Distance_A  19   0.293772   0.222181      0.346605
#
#    Spearman_p  Abs_Pearson_r  Abs_Spearman_rho  Mean_Abs_Correlation
# 0    0.000175       0.728209          0.757001              0.742605
# 1    0.003854       0.575878          0.629801              0.602839
# 2    0.003854       0.575878          0.629801              0.602839
# 3    0.007966       0.557718          0.589015              0.573367
# 4    0.020932       0.573648          0.525223              0.549436
# 5    0.027804       0.383662          0.503959              0.443810
# 6    0.077534       0.313902          0.414650              0.364276
# 7    0.079222       0.304010          0.412523              0.358267
# 8    0.095656       0.305549          0.393386              0.349467
# 9    0.146012       0.293772          0.346605              0.320188
# ====================================================================================================
# ✓ ALL PROCESSING FINISHED
# ====================================================================================================
