# %% [markdown]
# <a href="https://colab.research.google.com/github/bangaru01/C_programing/blob/main/CREST_TS_Conformer_Puckering_Analysis_Cycloetherification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

"""
============================================================
TS RING-PUCKER ANALYSIS
CREST + Cremer-Pople + Six-Ring-Torsion Deduplication
============================================================

Purpose
-------
1. Run constrained CREST on each input XYZ structure.
2. Preserve the forming O17-C22 distance using a CREST constraint.
3. Calculate Cremer-Pople puckering parameters.
4. Calculate six sequential ring torsions.
5. Remove conformers that have the same six-torsion pattern
   within the specified tolerance.
6. Keep the lowest-energy conformer for each unique puckering class.
7. Process all XYZ structures with checkpoint/resume support.

IMPORTANT
---------
CREST structures are constrained conformers/minima.
They are NOT verified transition states.

Use retained structures as starting geometries for
subsequent TS optimization and frequency calculations.
"""


# ============================================================
# BLOCK 1 — INSTALL CREST/xTB
# ============================================================

# !apt-get -qq update
# !apt-get -qq install -y xtb

print("Checking xTB:")
# !xtb --version

print("\nInstalling CREST:")
# !wget -q -O /content/crest.tar.xz \
    "https://github.com/crest-lab/crest/releases/download/latest/crest-gnu-12-ubuntu-latest.tar.xz"

# !rm -rf /content/crest
# !tar -xf /content/crest.tar.xz -C /content
# !chmod +x /content/crest/crest

print("\nChecking CREST:")
# !/content/crest/crest --version


# ============================================================
# BLOCK 2 — IMPORTS + GOOGLE DRIVE
# ============================================================

from google.colab import drive
drive.mount("/content/drive")

from pathlib import Path
import json
import os
import re
import shutil
import subprocess
import time

import numpy as np
import pandas as pd

print("\nPython environment ready.")


# ============================================================
# BLOCK 3 — USER SETTINGS
# ============================================================

# ------------------------------------------------------------
# Main input folder
# ------------------------------------------------------------

DRIVE_FOLDER = Path(
    "/content/drive/MyDrive/Cycloetherification_xyz_files"
)

# All persistent results will be saved here.
RESULTS_FOLDER = DRIVE_FOLDER / "CREST_results"
RESULTS_FOLDER.mkdir(parents=True, exist_ok=True)


# ------------------------------------------------------------
# Ring definition
# ------------------------------------------------------------

# Six ring atoms in connectivity order.
# Atom numbering is 1-based, as used in your XYZ files.
ring_atoms = [17, 18, 19, 20, 21, 22]


# ------------------------------------------------------------
# Forming bond
# ------------------------------------------------------------

# Bond constrained during CREST.
forming_bond = [17, 22]


# ------------------------------------------------------------
# Constraint force constant
# ------------------------------------------------------------

fc = 1.0


# ------------------------------------------------------------
# Single-structure CREST settings
# ------------------------------------------------------------

method = "gfn2"
quick_mode = True
threads = 2


# ------------------------------------------------------------
# Torsion-based deduplication
# ------------------------------------------------------------

# Two conformers are considered the same ring-pucker family
# when ALL SIX torsions differ by <= this value.
torsion_tolerance_deg = 5.0


# ------------------------------------------------------------
# Batch CREST settings
# ------------------------------------------------------------

batch_method = "gff"
batch_quick_mode = True
batch_threads = 2
batch_timeout_seconds = 1800


# ------------------------------------------------------------
# Optional per-file atom-number overrides
# ------------------------------------------------------------

# Normally leave this empty.
#
# Example:
#
# OVERRIDES = {
#     "RR_example.xyz": {
#         "ring_atoms": [17, 18, 19, 20, 21, 22],
#         "forming_bond": [17, 22],
#     }
# }

OVERRIDES = {}


# ------------------------------------------------------------
# CREST executable
# ------------------------------------------------------------

CREST_EXECUTABLE = "/content/crest/crest"


# ------------------------------------------------------------
# Basic checks
# ------------------------------------------------------------

if not DRIVE_FOLDER.exists():
    raise FileNotFoundError(
        f"Input folder does not exist:\n{DRIVE_FOLDER}"
    )

if not Path(CREST_EXECUTABLE).exists():
    raise FileNotFoundError(
        f"CREST executable not found:\n{CREST_EXECUTABLE}"
    )

if len(ring_atoms) != 6:
    raise ValueError(
        "ring_atoms must contain exactly six atoms."
    )

if len(forming_bond) != 2:
    raise ValueError(
        "forming_bond must contain exactly two atoms."
    )

if method not in {"gfn2", "gff"}:
    raise ValueError(
        "method must be 'gfn2' or 'gff'."
    )

if batch_method not in {"gfn2", "gff"}:
    raise ValueError(
        "batch_method must be 'gfn2' or 'gff'."
    )


print("\n============================================================")
print("USER SETTINGS")
print("============================================================")
print("Input folder       :", DRIVE_FOLDER)
print("Results folder     :", RESULTS_FOLDER)
print("Ring atoms         :", ring_atoms)
print("Forming bond       :", forming_bond)
print("Force constant     :", fc)
print("Batch method       :", batch_method)
print("Batch quick mode   :", batch_quick_mode)
print("Batch threads      :", batch_threads)
print("Batch timeout (s)  :", batch_timeout_seconds)
print("Torsion tolerance  :", torsion_tolerance_deg, "degrees")


# ============================================================
# BLOCK 4 — XYZ FUNCTIONS
# ============================================================

def parse_energy_from_comment(comment):
    """
    Extract an energy from an XYZ comment line.

    CREST comment formats can vary, so several patterns
    are checked.
    """

    patterns = [
        r"energy\s*=\s*([-+]?\d+(?:\.\d*)?(?:[Ee][-+]?\d+)?)",
        r"\bE\s*=\s*([-+]?\d+(?:\.\d*)?(?:[Ee][-+]?\d+)?)",
        r"([-+]?\d+\.\d+(?:[Ee][-+]?\d+)?)",
    ]

    for pattern in patterns:

        match = re.search(
            pattern,
            comment,
            flags=re.IGNORECASE
        )

        if match:
            return float(match.group(1))

    return np.nan


def read_xyz_frames(path):
    """
    Read one or more XYZ structures.

    Returns
    -------
    list of dictionaries

    Each dictionary contains:
        atoms
        coords
        comment
        energy_Eh
    """

    path = Path(path)

    with path.open("r") as f:
        lines = f.readlines()

    frames = []
    position = 0

    while position < len(lines):

        # Skip blank lines.
        if not lines[position].strip():
            position += 1
            continue

        # Number of atoms.
        try:
            n_atoms = int(lines[position].strip())
        except ValueError as exc:
            raise ValueError(
                f"Invalid atom-count line at line "
                f"{position + 1} in {path}"
            ) from exc

        # XYZ frame length.
        end = position + n_atoms + 2

        if end > len(lines):
            raise ValueError(
                f"Incomplete XYZ frame in {path}"
            )

        comment = lines[position + 1].rstrip("\n")

        atom_lines = lines[position + 2:end]

        atoms = []
        coords = []

        for line_number, line in enumerate(
            atom_lines,
            start=position + 3
        ):

            parts = line.split()

            if len(parts) < 4:
                raise ValueError(
                    f"Invalid XYZ line {line_number} "
                    f"in {path}: {line}"
                )

            atoms.append(parts[0])

            coords.append([
                float(parts[1]),
                float(parts[2]),
                float(parts[3]),
            ])

        frames.append({
            "atoms": atoms,
            "coords": np.asarray(
                coords,
                dtype=float
            ),
            "comment": comment,
            "energy_Eh": parse_energy_from_comment(
                comment
            ),
        })

        position = end

    return frames


def write_xyz_frames(frames, path):
    """
    Write one or more XYZ structures.
    """

    path = Path(path)

    with path.open("w") as f:

        for frame in frames:

            atoms = frame["atoms"]
            coords = frame["coords"]
            comment = frame.get("comment", "")

            f.write(f"{len(atoms)}\n")
            f.write(f"{comment}\n")

            for element, xyz in zip(atoms, coords):

                f.write(
                    f"{element:2s} "
                    f"{xyz[0]: .10f} "
                    f"{xyz[1]: .10f} "
                    f"{xyz[2]: .10f}\n"
                )


def validate_atom_indices(frame, indices, name):
    """
    Validate 1-based atom numbers.
    """

    n_atoms = len(frame["atoms"])

    if not indices:
        raise ValueError(
            f"{name} cannot be empty."
        )

    if len(set(indices)) != len(indices):
        raise ValueError(
            f"{name} contains duplicate atom indices."
        )

    if any(
        i < 1 or i > n_atoms
        for i in indices
    ):
        raise IndexError(
            f"{name}={indices} is invalid for "
            f"a structure with {n_atoms} atoms."
        )


def distance_from_frame(frame, i, j):
    """
    Calculate distance between two 1-based atoms in Å.
    """

    validate_atom_indices(
        frame,
        [i, j],
        "distance_atoms"
    )

    coords = frame["coords"]

    return float(
        np.linalg.norm(
            coords[i - 1] - coords[j - 1]
        )
    )


# ============================================================
# BLOCK 5 — RING / CREMER–POPLE / TORSION FUNCTIONS
# ============================================================

def cremer_pople_6(ring_coords):
    """
    Calculate Cremer-Pople Q, theta and phi
    for a six-membered ring.

    ring_coords must contain six atoms in
    connectivity order.
    """

    R = np.asarray(
        ring_coords,
        dtype=float
    )

    if R.shape != (6, 3):
        raise ValueError(
            "Expected ring coordinates with shape "
            f"(6,3), got {R.shape}"
        )

    # Center the ring.
    centered = R - R.mean(axis=0)

    # Best-fit ring plane.
    _, _, vh = np.linalg.svd(
        centered,
        full_matrices=False
    )

    normal = vh[-1]

    # Out-of-plane coordinates.
    z = centered @ normal

    j = np.arange(6)

    # q2 cosine component.
    c = np.sqrt(2.0 / 6.0) * np.sum(
        z * np.cos(
            2.0 * np.pi * j / 3.0
        )
    )

    # q2 sine component.
    s = -np.sqrt(2.0 / 6.0) * np.sum(
        z * np.sin(
            2.0 * np.pi * j / 3.0
        )
    )

    q2 = np.sqrt(
        c**2 + s**2
    )

    # q3 component.
    q3 = np.sqrt(1.0 / 6.0) * np.sum(
        z * ((-1.0) ** j)
    )

    # Total puckering amplitude.
    Q = float(
        np.sqrt(
            q2**2 + q3**2
        )
    )

    if Q < 1e-12:
        return 0.0, 0.0, 0.0

    theta = float(
        np.degrees(
            np.arccos(
                np.clip(
                    q3 / Q,
                    -1.0,
                    1.0
                )
            )
        )
    )

    phi = float(
        np.degrees(
            np.arctan2(s, c)
        ) % 360.0
    )

    return Q, theta, phi


def classify_6ring(theta, phi):
    """
    Approximate six-membered-ring pucker classification.

    Classification is heuristic and should be interpreted
    together with the actual Q/theta/phi values.
    """

    theta = float(theta)
    phi = float(phi) % 360.0

    # Chair region.
    if theta < 15.0 or theta > 165.0:
        return "Chair (C)"

    # Boat / twist-boat region.
    if 75.0 <= theta <= 105.0:

        m = phi % 60.0

        if m < 15.0 or m > 45.0:
            return "Boat (B)"

        return "Twist-boat/Skew (S)"

    # Envelope / half-chair region.
    if (
        35.0 <= theta <= 65.0
        or
        115.0 <= theta <= 145.0
    ):

        m = phi % 60.0

        if m < 15.0 or m > 45.0:
            return "Envelope (E)"

        return "Half-chair (H)"

    return "Intermediate"


def dihedral_angle(coords, i, j, k, l):
    """
    Calculate a dihedral angle in degrees.

    Atom indices here are 0-based.
    """

    p0, p1, p2, p3 = coords[
        [i, j, k, l]
    ]

    b0 = -(p1 - p0)
    b1 = p2 - p1
    b2 = p3 - p2

    b1_norm = np.linalg.norm(b1)

    if b1_norm < 1e-12:
        raise ValueError(
            "Central bond has zero length."
        )

    b1 = b1 / b1_norm

    v = (
        b0
        - np.dot(b0, b1) * b1
    )

    w = (
        b2
        - np.dot(b2, b1) * b1
    )

    if np.linalg.norm(v) < 1e-12:
        raise ValueError(
            "First projected vector is too small."
        )

    if np.linalg.norm(w) < 1e-12:
        raise ValueError(
            "Second projected vector is too small."
        )

    x = np.dot(v, w)

    y = np.dot(
        np.cross(b1, v),
        w
    )

    return float(
        np.degrees(
            np.arctan2(y, x)
        )
    )


def ring_torsions(frame, ring_atoms):
    """
    Calculate six sequential ring torsions.

    For:
        [a0,a1,a2,a3,a4,a5]

    calculate:

        a0-a1-a2-a3
        a1-a2-a3-a4
        a2-a3-a4-a5
        a3-a4-a5-a0
        a4-a5-a0-a1
        a5-a0-a1-a2
    """

    if len(ring_atoms) != 6:
        raise ValueError(
            "ring_atoms must contain six atoms."
        )

    validate_atom_indices(
        frame,
        ring_atoms,
        "ring_atoms"
    )

    indices = [
        atom - 1
        for atom in ring_atoms
    ]

    coords = frame["coords"]

    torsions = []

    for shift in range(6):

        quartet = [
            indices[
                (shift + offset) % 6
            ]
            for offset in range(4)
        ]

        torsions.append(
            dihedral_angle(
                coords,
                *quartet
            )
        )

    return np.asarray(
        torsions,
        dtype=float
    )


def torsion_differences(
    torsions_a,
    torsions_b
):
    """
    Calculate smallest periodic absolute
    differences between two torsion vectors.
    """

    a = np.asarray(
        torsions_a,
        dtype=float
    )

    b = np.asarray(
        torsions_b,
        dtype=float
    )

    if a.shape != b.shape:
        raise ValueError(
            "Torsion vectors have different shapes."
        )

    return np.abs(
        (a - b + 180.0) % 360.0
        - 180.0
    )


# ============================================================
# BLOCK 6 — CREST EXECUTION
# ============================================================

def write_constraint_file(
    workdir,
    forming_bond,
    fc
):
    """
    Write the CREST constraint input.
    """

    workdir = Path(workdir)

    workdir.mkdir(
        parents=True,
        exist_ok=True
    )

    constraint_text = (
        "$constrain\n"
        f"distance: "
        f"{forming_bond[0]}, "
        f"{forming_bond[1]}, auto\n"
        f"force constant={fc}\n"
        "$end\n"
    )

    path = workdir / "constraints.inp"

    path.write_text(
        constraint_text
    )

    return path


def run_crest_live(
    xyz_file,
    workdir,
    forming_bond,
    fc=1.0,
    method="gfn2",
    quick_mode=True,
    threads=2,
    timeout_seconds=1800
):
    """
    Run one constrained CREST calculation.

    stdout is printed live and saved.
    stderr is also saved.
    """

    xyz_file = Path(xyz_file)
    workdir = Path(workdir)

    if not xyz_file.exists():
        raise FileNotFoundError(
            f"XYZ file not found:\n{xyz_file}"
        )

    if method not in {"gfn2", "gff"}:
        raise ValueError(
            "method must be 'gfn2' or 'gff'."
        )

    if int(threads) < 1:
        raise ValueError(
            "threads must be >= 1."
        )

    if (
        timeout_seconds is not None
        and float(timeout_seconds) <= 0
    ):
        raise ValueError(
            "timeout_seconds must be positive."
        )

    # Start from a clean temporary directory.
    if workdir.exists():
        shutil.rmtree(workdir)

    workdir.mkdir(
        parents=True,
        exist_ok=True
    )

    # Read input structure.
    input_frames = read_xyz_frames(
        xyz_file
    )

    if not input_frames:
        raise ValueError(
            f"No structure found in {xyz_file}"
        )

    validate_atom_indices(
        input_frames[0],
        forming_bond,
        "forming_bond"
    )

    # CREST expects the structure in its working directory.
    shutil.copy2(
        xyz_file,
        workdir / "struc.xyz"
    )

    # Write constraint.
    constraint_path = write_constraint_file(
        workdir,
        forming_bond,
        fc
    )

    # Build CREST command.
    cmd = [
        CREST_EXECUTABLE,
        "struc.xyz",
        "--cinp",
        constraint_path.name,
        "--T",
        str(int(threads)),
    ]

    if method == "gff":
        cmd.append("--gfnff")

    if quick_mode:
        cmd.append("-mquick")

    print("\nCREST command:")
    print(" ".join(cmd))
    print()

    stdout_path = (
        workdir / "crest_stdout.log"
    )

    stderr_path = (
        workdir / "crest_stderr.log"
    )

    start_time = time.time()

    process = subprocess.Popen(
        cmd,
        cwd=workdir,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        bufsize=1
    )

    stdout_lines = []
    stderr_text = ""
    timed_out = False

    try:

        while True:

            line = (
                process.stdout.readline()
                if process.stdout
                else ""
            )

            if line:

                print(
                    line,
                    end="",
                    flush=True
                )

                stdout_lines.append(
                    line
                )

            if process.poll() is not None:
                break

            if (
                timeout_seconds is not None
                and
                time.time() - start_time
                > float(timeout_seconds)
            ):

                timed_out = True

                process.kill()

                break

            if not line:
                time.sleep(0.1)

        # Collect remaining output.
        remaining_stdout = (
            process.stdout.read()
            if process.stdout
            else ""
        )

        if remaining_stdout:

            print(
                remaining_stdout,
                end="",
                flush=True
            )

            stdout_lines.append(
                remaining_stdout
            )

        stderr_text = (
            process.stderr.read()
            if process.stderr
            else ""
        )

        return_code = process.wait()

    finally:

        if process.poll() is None:

            process.kill()
            process.wait()

    # Save logs.
    stdout_path.write_text(
        "".join(stdout_lines)
    )

    stderr_path.write_text(
        stderr_text
    )

    elapsed = (
        time.time()
        - start_time
    )

    print()
    print(
        f"CREST runtime: {elapsed:.1f} s"
    )

    print(
        f"Return code: {return_code}"
    )

    if timed_out:

        raise TimeoutError(
            f"CREST exceeded "
            f"{timeout_seconds} seconds for "
            f"{xyz_file.name}"
        )

    if return_code != 0:

        raise RuntimeError(
            f"CREST failed for "
            f"{xyz_file.name}\n\n"
            f"Working directory:\n"
            f"{workdir}\n\n"
            f"Return code: {return_code}\n\n"
            f"Last stderr:\n"
            f"{stderr_text[-3000:]}"
        )

    conformer_file = (
        workdir / "crest_conformers.xyz"
    )

    if not conformer_file.exists():

        raise FileNotFoundError(
            "CREST finished but did not create:\n"
            f"{conformer_file}"
        )

    if conformer_file.stat().st_size == 0:

        raise ValueError(
            f"CREST output is empty:\n"
            f"{conformer_file}"
        )

    return conformer_file


# Backward-compatible wrapper.
def run_crest(*args, **kwargs):
    return run_crest_live(
        *args,
        **kwargs
    )


# ============================================================
# BLOCK 7 — CONFORMER ANALYSIS
# ============================================================

def analyze_conformers(
    conformer_file,
    ring_atoms,
    forming_bond
):
    """
    Calculate structural descriptors for every CREST conformer.

    Returns
    -------
    list of dictionaries
    """

    frames = read_xyz_frames(
        conformer_file
    )

    if not frames:
        raise ValueError(
            f"No conformers found in "
            f"{conformer_file}"
        )

    records = []

    for original_index, frame in enumerate(
        frames,
        start=1
    ):

        validate_atom_indices(
            frame,
            ring_atoms,
            "ring_atoms"
        )

        validate_atom_indices(
            frame,
            forming_bond,
            "forming_bond"
        )

        # Ring coordinates.
        ring_coords = frame["coords"][
            [
                atom - 1
                for atom in ring_atoms
            ]
        ]

        # Cremer-Pople.
        Q, theta, phi = cremer_pople_6(
            ring_coords
        )

        # Six torsions.
        torsions = ring_torsions(
            frame,
            ring_atoms
        )

        # Forming bond.
        bond_distance = distance_from_frame(
            frame,
            forming_bond[0],
            forming_bond[1]
        )

        record = {
            "original_conformer":
                original_index,

            "energy_Eh":
                frame["energy_Eh"],

            "forming_bond_A":
                bond_distance,

            "Q_A":
                Q,

            "theta_deg":
                theta,

            "phi_deg":
                phi,

            "classification":
                classify_6ring(
                    theta,
                    phi
                ),
        }

        for i, torsion in enumerate(
            torsions,
            start=1
        ):

            record[
                f"torsion_{i}_deg"
            ] = torsion

        records.append({
            "frame": frame,
            "torsions": torsions,
            "record": record
        })

    return records


# ============================================================
# BLOCK 8 — TORSION DEDUPLICATION
# ============================================================

def deduplicate_by_six_torsions(
    analyzed_records,
    tolerance_deg=5.0
):
    """
    Sort conformers by energy and retain the lowest-energy
    conformer from each unique six-torsion family.

    Two conformers are considered duplicates when ALL SIX
    torsion differences are <= tolerance_deg.
    """

    # --------------------------------------------------------
    # Sort by energy.
    # Finite energies first, lowest energy first.
    # --------------------------------------------------------

    analyzed_records = sorted(
        analyzed_records,
        key=lambda item: (
            not np.isfinite(
                item["record"]["energy_Eh"]
            ),
            item["record"]["energy_Eh"]
            if np.isfinite(
                item["record"]["energy_Eh"]
            )
            else np.inf
        )
    )

    retained = []
    duplicates = []

    # --------------------------------------------------------
    # Compare every conformer with retained conformers.
    # --------------------------------------------------------

    for item in analyzed_records:

        frame = item["frame"]
        torsions = item["torsions"]
        record = item["record"]

        duplicate_of = None
        duplicate_diff = None

        for retained_item in retained:

            differences = torsion_differences(
                torsions,
                retained_item["torsions"]
            )

            if np.all(
                differences <= tolerance_deg
            ):

                duplicate_of = (
                    retained_item[
                        "retained_conformer"
                    ]
                )

                duplicate_diff = differences

                break

        # ----------------------------------------------------
        # New unique torsion family.
        # ----------------------------------------------------

        if duplicate_of is None:

            retained_number = (
                len(retained) + 1
            )

            retained_item = {
                "frame": frame,
                "torsions": torsions,
                "retained_conformer":
                    retained_number
            }

            retained.append(
                retained_item
            )

            record.update({

                "retained_conformer":
                    retained_number,

                "status":
                    "retained",

                "duplicate_of":
                    np.nan,

                "max_torsion_difference_deg":
                    0.0,

                "mean_torsion_difference_deg":
                    0.0,
            })

        # ----------------------------------------------------
        # Duplicate torsion family.
        # ----------------------------------------------------

        else:

            record.update({

                "retained_conformer":
                    np.nan,

                "status":
                    "removed_torsion_duplicate",

                "duplicate_of":
                    duplicate_of,

                "max_torsion_difference_deg":
                    float(
                        np.max(
                            duplicate_diff
                        )
                    ),

                "mean_torsion_difference_deg":
                    float(
                        np.mean(
                            duplicate_diff
                        )
                    ),
            })

            duplicates.append(
                record.copy()
            )

        # Store retained record separately.
        if duplicate_of is None:

            retained_item["record"] = (
                record.copy()
            )

    # --------------------------------------------------------
    # Create data tables.
    # --------------------------------------------------------

    retained_records = [
        item["record"]
        for item in retained
    ]

    retained_df = pd.DataFrame(
        retained_records
    )

    duplicates_df = pd.DataFrame(
        duplicates
    )

    # --------------------------------------------------------
    # Relative energy.
    # --------------------------------------------------------

    if len(retained_df):

        minimum_energy = (
            retained_df["energy_Eh"].min()
        )

        if np.isfinite(
            minimum_energy
        ):

            retained_df["rel_kcal"] = (
                (
                    retained_df["energy_Eh"]
                    - minimum_energy
                )
                * 627.5095
            )

        else:

            retained_df["rel_kcal"] = np.nan

        # Sort retained structures by energy.
        order = np.argsort(
            retained_df[
                "rel_kcal"
            ].fillna(np.inf).values
        )

        retained_df = (
            retained_df.iloc[order]
            .reset_index(drop=True)
        )

        # IMPORTANT:
        # retained frames must follow the same order
        # as retained_df.
        retained_lookup = {
            int(item["record"][
                "retained_conformer"
            ]): item
            for item in retained
        }

        sorted_retained = []

        for retained_number in (
            retained_df[
                "retained_conformer"
            ].astype(int)
        ):

            sorted_retained.append(
                retained_lookup[
                    retained_number
                ]
            )

        retained = sorted_retained

    return (
        retained,
        retained_df,
        duplicates_df
    )


# ============================================================
# BLOCK 9 — PROCESS ONE STRUCTURE
# ============================================================

def process_one_structure(
    xyz_file,
    results_folder,
    ring_atoms,
    forming_bond,
    fc=1.0,
    method="gff",
    quick_mode=True,
    threads=2,
    torsion_tolerance_deg=5.0,
    timeout_seconds=1800
):
    """
    Run CREST, analyze conformers, deduplicate by torsions,
    and save all results for one input structure.
    """

    xyz_file = Path(xyz_file)
    results_folder = Path(
        results_folder
    )

    tag = xyz_file.stem

    # Temporary CREST working directory.
    workdir = (
        Path("/content")
        / f"crest_run_{tag}"
    )

    # Permanent output directory.
    output_dir = (
        results_folder
        / f"{tag}_CREST_conformations"
    )

    output_dir.mkdir(
        parents=True,
        exist_ok=True
    )

    print("\n")
    print("=" * 80)
    print(f"PROCESSING: {tag}")
    print("=" * 80)

    # --------------------------------------------------------
    # 1. Run CREST.
    # --------------------------------------------------------

    conformer_file = run_crest_live(
        xyz_file=xyz_file,
        workdir=workdir,
        forming_bond=forming_bond,
        fc=fc,
        method=method,
        quick_mode=quick_mode,
        threads=threads,
        timeout_seconds=timeout_seconds
    )

    # --------------------------------------------------------
    # 2. Analyze all CREST conformers.
    # --------------------------------------------------------

    analyzed = analyze_conformers(
        conformer_file=conformer_file,
        ring_atoms=ring_atoms,
        forming_bond=forming_bond
    )

    raw_count = len(analyzed)

    # --------------------------------------------------------
    # 3. Deduplicate.
    # --------------------------------------------------------

    (
        retained,
        retained_df,
        duplicates_df
    ) = deduplicate_by_six_torsions(
        analyzed,
        tolerance_deg=
            torsion_tolerance_deg
    )

    # --------------------------------------------------------
    # 4. Preserve raw CREST ensemble.
    # --------------------------------------------------------

    shutil.copy2(
        conformer_file,
        output_dir
        / f"{tag}_raw_crest_conformers.xyz"
    )

    # --------------------------------------------------------
    # 5. Save individual retained conformers.
    # --------------------------------------------------------

    for item in retained:

        frame = dict(
            item["frame"]
        )

        retained_number = int(
            item["record"][
                "retained_conformer"
            ]
        )

        energy = item["record"][
            "energy_Eh"
        ]

        rel_energy = item["record"].get(
            "rel_kcal",
            np.nan
        )

        frame["comment"] = (
            f"retained_conformer="
            f"{retained_number} "
            f"energy_Eh="
            f"{energy:.12f} "
            f"rel_kcal="
            f"{rel_energy:.6f}"
        )

        output_path = (
            output_dir
            / f"{tag}_retained_"
            f"{retained_number:03d}.xyz"
        )

        write_xyz_frames(
            [frame],
            output_path
        )

    # --------------------------------------------------------
    # 6. Save retained ensemble.
    # --------------------------------------------------------

    retained_frames = [
        item["frame"]
        for item in retained
    ]

    retained_ensemble_path = (
        output_dir
        / f"{tag}_retained_ensemble.xyz"
    )

    # Always create the file.
    write_xyz_frames(
        retained_frames,
        retained_ensemble_path
    )

    # --------------------------------------------------------
    # 7. Save CSV tables.
    # --------------------------------------------------------

    retained_csv = (
        output_dir
        / f"{tag}_retained_pucker_results.csv"
    )

    duplicates_csv = (
        output_dir
        / f"{tag}_torsion_duplicates.csv"
    )

    retained_df.to_csv(
        retained_csv,
        index=False
    )

    duplicates_df.to_csv(
        duplicates_csv,
        index=False
    )

    # --------------------------------------------------------
    # 8. Save metadata.
    # --------------------------------------------------------

    metadata = {

        "source_file":
            str(xyz_file),

        "ring_atoms":
            list(ring_atoms),

        "forming_bond":
            list(forming_bond),

        "constraint_force_constant":
            fc,

        "method":
            method,

        "quick_mode":
            quick_mode,

        "threads":
            threads,

        "torsion_tolerance_deg":
            torsion_tolerance_deg,

        "raw_conformer_count":
            raw_count,

        "retained_conformer_count":
            len(retained),

        "removed_torsion_duplicate_count":
            len(duplicates_df),
    }

    metadata_path = (
        output_dir
        / f"{tag}_metadata.json"
    )

    with metadata_path.open(
        "w"
    ) as f:

        json.dump(
            metadata,
            f,
            indent=2
        )

    print()
    print(
        f"{tag}: "
        f"{raw_count} CREST conformers"
    )

    print(
        f"{tag}: "
        f"{len(retained)} retained"
    )

    print(
        f"{tag}: "
        f"{len(duplicates_df)} torsion duplicates removed"
    )

    return (
        retained_df,
        duplicates_df
    )


# ============================================================
# BLOCK 10 — VALIDATE INPUT FILES
# ============================================================

xyz_files = sorted(
    DRIVE_FOLDER.glob("*.xyz")
)

print("\n")
print("=" * 80)
print("INPUT VALIDATION")
print("=" * 80)

print(
    f"Found {len(xyz_files)} XYZ files."
)

if not xyz_files:

    raise FileNotFoundError(
        f"No XYZ files found in:\n"
        f"{DRIVE_FOLDER}"
    )


validation_records = []


for xyz_file in xyz_files:

    config = {

        "ring_atoms":
            list(ring_atoms),

        "forming_bond":
            list(forming_bond),
    }

    config.update(
        OVERRIDES.get(
            xyz_file.name,
            {}
        )
    )

    try:

        frames = read_xyz_frames(
            xyz_file
        )

        if not frames:

            raise ValueError(
                "No XYZ frames found."
            )

        first_frame = frames[0]

        validate_atom_indices(
            first_frame,
            config["ring_atoms"],
            "ring_atoms"
        )

        validate_atom_indices(
            first_frame,
            config["forming_bond"],
            "forming_bond"
        )

        initial_distance = (
            distance_from_frame(
                first_frame,
                config["forming_bond"][0],
                config["forming_bond"][1]
            )
        )

        validation_records.append({

            "structure":
                xyz_file.name,

            "n_atoms":
                len(first_frame["atoms"]),

            "input_frames":
                len(frames),

            "initial_forming_bond_A":
                initial_distance,

            "status":
                "OK",

            "error":
                "",
        })

    except Exception as exc:

        validation_records.append({

            "structure":
                xyz_file.name,

            "n_atoms":
                np.nan,

            "input_frames":
                np.nan,

            "initial_forming_bond_A":
                np.nan,

            "status":
                "FAILED",

            "error":
                repr(exc),
        })


validation_df = pd.DataFrame(
    validation_records
)

display(validation_df)


validation_path = (
    RESULTS_FOLDER
    / "INPUT_validation.csv"
)

validation_df.to_csv(
    validation_path,
    index=False
)


if (
    validation_df["status"]
    != "OK"
).any():

    raise RuntimeError(
        "Input validation failed.\n\n"
        "Check:\n"
        f"{validation_path}\n\n"
        "Fix the input files before "
        "running the batch."
    )


print(
    "\nAll input XYZ files passed validation."
)


# ============================================================
# BLOCK 11 — BATCH PROCESSING + CHECKPOINT / RESUME
# ============================================================

def structure_output_dir(
    results_folder,
    tag
):
    """
    Return permanent output directory
    for one structure.
    """

    return (
        Path(results_folder)
        / f"{tag}_CREST_conformations"
    )


def structure_is_complete(
    results_folder,
    tag
):
    """
    Check whether all important output files
    already exist.

    If yes, the structure will NOT be recalculated.
    """

    output_dir = structure_output_dir(
        results_folder,
        tag
    )

    required_files = [

        output_dir
        / f"{tag}_raw_crest_conformers.xyz",

        output_dir
        / f"{tag}_retained_ensemble.xyz",

        output_dir
        / f"{tag}_retained_pucker_results.csv",

        output_dir
        / f"{tag}_torsion_duplicates.csv",

        output_dir
        / f"{tag}_metadata.json",
    ]

    return all(
        path.exists()
        and path.stat().st_size > 0
        for path in required_files
    )


def load_completed_structure(
    results_folder,
    tag
):
    """
    Load previously completed CSV results.
    """

    output_dir = structure_output_dir(
        results_folder,
        tag
    )

    retained_df = pd.read_csv(
        output_dir
        / f"{tag}_retained_pucker_results.csv"
    )

    duplicates_df = pd.read_csv(
        output_dir
        / f"{tag}_torsion_duplicates.csv"
    )

    return (
        retained_df,
        duplicates_df
    )


# ------------------------------------------------------------
# Batch output files
# ------------------------------------------------------------

progress_path = (
    RESULTS_FOLDER
    / "BATCH_progress.csv"
)

failure_path = (
    RESULTS_FOLDER
    / "BATCH_failures.csv"
)

retained_path = (
    RESULTS_FOLDER
    / "ALL_retained_pucker_results.csv"
)

duplicates_path = (
    RESULTS_FOLDER
    / "ALL_torsion_duplicates.csv"
)


# ------------------------------------------------------------
# Containers for results
# ------------------------------------------------------------

all_retained = []
all_duplicates = []

completed_records = []
failure_records = []


print("\n")
print("=" * 80)
print("STARTING CREST BATCH")
print("=" * 80)


# ------------------------------------------------------------
# Main batch loop
# ------------------------------------------------------------

for file_number, xyz_file in enumerate(
    xyz_files,
    start=1
):

    tag = xyz_file.stem

    print("\n")
    print("=" * 80)

    print(
        f"[{file_number}/{len(xyz_files)}] "
        f"Processing: {xyz_file.name}"
    )

    print("=" * 80)


    # --------------------------------------------------------
    # File-specific configuration.
    # --------------------------------------------------------

    config = {

        "ring_atoms":
            list(ring_atoms),

        "forming_bond":
            list(forming_bond),
    }

    config.update(
        OVERRIDES.get(
            xyz_file.name,
            {}
        )
    )


    try:

        # ----------------------------------------------------
        # RESUME CHECK
        # ----------------------------------------------------

        if structure_is_complete(
            RESULTS_FOLDER,
            tag
        ):

            print()
            print(
                "Already complete."
            )

            print(
                "Loading saved results:"
                f" {tag}"
            )

            retained_df, duplicates_df = (
                load_completed_structure(
                    RESULTS_FOLDER,
                    tag
                )
            )

        else:

            # ------------------------------------------------
            # RUN CREST
            # ------------------------------------------------

            retained_df, duplicates_df = (
                process_one_structure(

                    xyz_file=xyz_file,

                    results_folder=
                        RESULTS_FOLDER,

                    ring_atoms=
                        config["ring_atoms"],

                    forming_bond=
                        config["forming_bond"],

                    fc=fc,

                    method=
                        batch_method,

                    quick_mode=
                        batch_quick_mode,

                    threads=
                        batch_threads,

                    torsion_tolerance_deg=
                        torsion_tolerance_deg,

                    timeout_seconds=
                        batch_timeout_seconds
                )
            )


        # ----------------------------------------------------
        # Add structure name to retained table.
        # ----------------------------------------------------

        if len(retained_df):

            tmp = retained_df.copy()

            tmp.insert(
                0,
                "structure",
                tag
            )

            all_retained.append(
                tmp
            )


        # ----------------------------------------------------
        # Add structure name to duplicate table.
        # ----------------------------------------------------

        if len(duplicates_df):

            tmp = duplicates_df.copy()

            tmp.insert(
                0,
                "structure",
                tag
            )

            all_duplicates.append(
                tmp
            )


        # ----------------------------------------------------
        # Record successful completion.
        # ----------------------------------------------------

        completed_records.append({

            "structure":
                tag,

            "status":
                "completed",

            "retained_rows":
                len(retained_df),

            "duplicate_rows":
                len(duplicates_df),

            "error":
                "",
        })


        # ----------------------------------------------------
        # CHECKPOINT
        # ----------------------------------------------------

        if all_retained:

            pd.concat(
                all_retained,
                ignore_index=True
            ).to_csv(
                retained_path,
                index=False
            )


        if all_duplicates:

            pd.concat(
                all_duplicates,
                ignore_index=True
            ).to_csv(
                duplicates_path,
                index=False
            )


        pd.DataFrame(
            completed_records
        ).to_csv(
            progress_path,
            index=False
        )


        print()
        print(
            f"COMPLETED: {tag}"
        )

        print(
            f"Retained   : "
            f"{len(retained_df)}"
        )

        print(
            f"Duplicates : "
            f"{len(duplicates_df)}"
        )


    except Exception as exc:

        # ----------------------------------------------------
        # FAILURE
        # ----------------------------------------------------

        failure_record = {

            "structure":
                tag,

            "status":
                "failed",

            "error":
                repr(exc),
        }

        failure_records.append(
            failure_record
        )

        completed_records.append(
            failure_record
        )


        # Save failure checkpoint immediately.
        pd.DataFrame(
            completed_records
        ).to_csv(
            progress_path,
            index=False
        )

        pd.DataFrame(
            failure_records
        ).to_csv(
            failure_path,
            index=False
        )


        print()
        print(
            f"FAILED: {tag}"
        )

        print(
            repr(exc)
        )

        print(
            "The batch will continue "
            "with the next structure."
        )


# ============================================================
# BLOCK 12 — FINAL COMBINED RESULTS
# ============================================================

print("\n")
print("=" * 80)
print("CREATING FINAL COMBINED RESULTS")
print("=" * 80)


# ------------------------------------------------------------
# Combine retained results.
# ------------------------------------------------------------

if all_retained:

    all_retained_df = pd.concat(
        all_retained,
        ignore_index=True
    )

else:

    all_retained_df = pd.DataFrame()


# ------------------------------------------------------------
# Combine duplicate results.
# ------------------------------------------------------------

if all_duplicates:

    all_duplicates_df = pd.concat(
        all_duplicates,
        ignore_index=True
    )

else:

    all_duplicates_df = pd.DataFrame()


# ------------------------------------------------------------
# Failure table.
# ------------------------------------------------------------

failures_df = pd.DataFrame(
    failure_records
)


# ------------------------------------------------------------
# Save final tables.
# ------------------------------------------------------------

all_retained_df.to_csv(
    retained_path,
    index=False
)

all_duplicates_df.to_csv(
    duplicates_path,
    index=False
)

failures_df.to_csv(
    RESULTS_FOLDER
    / "ALL_batch_failures.csv",
    index=False
)


# ------------------------------------------------------------
# Pucker summary.
# ------------------------------------------------------------

if len(all_retained_df):

    summary_df = (

        all_retained_df

        .groupby(
            [
                "structure",
                "classification"
            ],
            dropna=False
        )

        .size()

        .reset_index(
            name="n_retained"
        )

        .sort_values(
            [
                "structure",
                "classification"
            ]
        )

        .reset_index(
            drop=True
        )
    )

    summary_path = (
        RESULTS_FOLDER
        / "SUMMARY_retained_puckers.csv"
    )

    summary_df.to_csv(
        summary_path,
        index=False
    )

    display(summary_df)

else:

    summary_df = pd.DataFrame()


# ------------------------------------------------------------
# Final batch summary.
# ------------------------------------------------------------

print("\n")
print("=" * 80)
print("BATCH FINISHED")
print("=" * 80)

print(
    f"Input structures : "
    f"{len(xyz_files)}"
)

print(
    f"Retained rows     : "
    f"{len(all_retained_df)}"
)

print(
    f"Duplicate rows    : "
    f"{len(all_duplicates_df)}"
)

print(
    f"Failed structures : "
    f"{len(failures_df)}"
)

print(
    f"Results folder    : "
    f"{RESULTS_FOLDER}"
)

print("\nMain output files:")

print(
    f"1. {retained_path}"
)

print(
    f"2. {duplicates_path}"
)

print(
    f"3. {RESULTS_FOLDER / 'ALL_batch_failures.csv'}"
)

print(
    f"4. {RESULTS_FOLDER / 'SUMMARY_retained_puckers.csv'}"
)

print(
    f"5. {RESULTS_FOLDER / 'INPUT_validation.csv'}"
)

print("\nDone.")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu noble InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package libmctc-lib0.
# (Reading database ... 122797 files and directories currently installed.)
# Preparing to unpack .../libmctc-lib0_0.3.1-3_amd64.deb ...
# Unpacking libmctc-lib0 (0.3.1-3) ...
# Selecting previously unselected package xtb.
# Preparing to unpack .../archives/xtb_6.6.1-1_amd64.deb ...
# Unpacking xtb (6.6.1-1) ...
# Setting up libmctc-lib0 (0.3.1-3) ...
# Setting up xtb (6.6.1-1) ...
# Processing triggers for man-db (2.12.0-4build2) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Checking xTB:
#       -----------------------------------------------------------
#      |                   =====================                   |
#      |                           x T B                           |
#      |                   =====================                   |
#      |                         S. Grimme                         |
#      |          Mulliken Center for Theoretical Chemistry        |
#      |                    University of Bonn                     |
#       -----------------------------------------------------------
#
#    * xtb version 6.6.1 (unknown) compiled by 'builduser@buildhost' on 2023-08-07
#
# normal termination of xtb
#
# Installing CREST:
#
# Checking CREST:
#
#        ╔════════════════════════════════════════════════╗
#        ║                                                ║
#        ║     ██████╗██████╗ ███████╗███████╗████████╗   ║
#        ║    ██╔════╝██╔══██╗██╔════╝██╔════╝╚══██╔══╝   ║
#        ║    ██║     ██████╔╝█████╗  ███████╗   ██║      ║
#        ║    ██║     ██╔══██╗██╔══╝  ╚════██║   ██║      ║
#        ║    ╚██████╗██║  ██║███████╗███████║   ██║      ║
#        ║     ╚═════╝╚═╝  ╚═╝╚══════╝╚══════╝   ╚═╝      ║
#        ║                                                ║
#        ║    Conformer-Rotamer Ensemble Sampling Tool    ║
#        ║            based on the xTB methods            ║
#        ║                                                ║
#        ╚════════════════════════════════════════════════╝
#         Version 3.0.2, Tue, 16 June 10:18:10, 06/16/2026
#         commit (cfdc301) compiled by 'usr@runnervm1li68'
#
#  crest 3.0.2
# Mounted at /content/drive
#
# Python environment ready.
#
# ============================================================
# USER SETTINGS
# ============================================================
# Input folder       : /content/drive/MyDrive/Cycloetherification_xyz_files
# Results folder     : /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results
# Ring atoms         : [17, 18, 19, 20, 21, 22]
# Forming bond       : [17, 22]
# Force constant     : 1.0
# Batch method       : gff
# Batch quick mode   : True
# Batch threads      : 2
# Batch timeout (s)  : 1800
# Torsion tolerance  : 5.0 degrees
#
#
# ================================================================================
# INPUT VALIDATION
# ================================================================================
# Found 34 XYZ files.
#                 structure  n_atoms  input_frames  initial_forming_bond_A  \
# 0           RR_CH2-Ph.xyz       57             1                2.230903
# 1      RR_CH2-dioxane.xyz       56             1                2.309687
# 2            RR_CH2CN.xyz       48             1                2.237502
# 3         RR_CH2CO2Me.xyz       53             1                2.318575
# 4        RR_CMe2CO2Me.xyz       59             1                2.262033
# 5               RR_Cy.xyz       60             1                2.315953
# 6               RR_Et.xyz       50             1                2.254818
# 7       RR_Me-Propane.xyz       56             1                2.225446
# 8               RR_Me.xyz       47             1                2.303139
# 9               RR_Ph.xyz       54             1                2.284585
# 10          RR_alkene.xyz       48             1                2.260186
# 11          RR_alkyne.xyz       46             1                2.256048
# 12           RR_allyl.xyz       51             1                2.250542
# 13  RR_dimethyl-allyl.xyz       57             1                2.294514
# 14             RR_iPr.xyz       53             1                2.322444
# 15             RR_nBu.xyz       56             1                2.262359
# 16             RR_tBu.xyz       56             1                2.312110
# 17          RS_CH2-Ph.xyz       57             1                2.241959
# 18     RS_CH2-dioxane.xyz       56             1                2.250584
# 19           RS_CH2CN.xyz       48             1                2.241016
# 20        RS_CH2CO2Me.xyz       53             1                2.280995
# 21       RS_CMe2CO2Me.xyz       59             1                2.282777
# 22              RS_Cy.xyz       60             1                2.233656
# 23              RS_Et.xyz       50             1                2.317321
# 24      RS_Me-Propane.xyz       56             1                2.224534
# 25              RS_Me.xyz       47             1                2.303682
# 26              RS_Ph.xyz       54             1                2.239074
# 27          RS_alkene.xyz       48             1                2.297728
# 28          RS_alkyne.xyz       46             1                2.274719
# 29           RS_allyl.xyz       51             1                2.301620
# 30  RS_dimethyl-allyl.xyz       57             1                2.248944
# 31             RS_iPr.xyz       53             1                2.233698
# 32             RS_nBu.xyz       56             1                2.319036
# 33             RS_tBu.xyz       56             1                2.254487
#
#    status error
# 0      OK
# 1      OK
# 2      OK
# 3      OK
# 4      OK
# 5      OK
# 6      OK
# 7      OK
# 8      OK
# 9      OK
# 10     OK
# 11     OK
# 12     OK
# 13     OK
# 14     OK
# 15     OK
# 16     OK
# 17     OK
# 18     OK
# 19     OK
# 20     OK
# 21     OK
# 22     OK
# 23     OK
# 24     OK
# 25     OK
# 26     OK
# 27     OK
# 28     OK
# 29     OK
# 30     OK
# 31     OK
# 32     OK
# 33     OK
# Streaming output truncated to the last 5000 lines.
#  -----------------------------------
#  Starting trial MTD to test settings
#  -----------------------------------
#  Trial MTD 1 runtime (1.0 ps) ...        0 min,  1.183 sec
#  Estimated runtime for one MTD (5.0 ps) on a single thread: 6 sec
#  Estimated runtime for a batch of 6 MTDs on 2 threads: 18 sec
#
# ********************************************************************************
# **                    N E W   I T E R A T I O N  C Y C L E                    **
# ********************************************************************************
#
#  ------------------------------
#  Meta-Dynamics Iteration 1
#  ------------------------------
#  list of applied metadynamics Vbias parameters:
# $metadyn    0.11800   1.000
# $metadyn    0.05900   1.000
# $metadyn    0.11800   0.500
# $metadyn    0.05900   0.500
# $metadyn    0.11800   0.250
# $metadyn    0.05900   0.250
#
#   ::::::::::::: starting MTD    1 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1180 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
#   ::::::::::::: starting MTD    4 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0590 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
# *MTD   1 completed successfully ...        0 min,  9.593 sec
#   ::::::::::::: starting MTD    2 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0590 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
# *MTD   4 completed successfully ...        0 min, 10.584 sec
#   ::::::::::::: starting MTD    5 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1180 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   2 completed successfully ...        0 min,  8.615 sec
#   ::::::::::::: starting MTD    3 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1180 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
# *MTD   5 completed successfully ...        0 min,  7.870 sec
#   ::::::::::::: starting MTD    6 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0590 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   3 completed successfully ...        0 min,  9.517 sec
# *MTD   6 completed successfully ...        0 min,  9.338 sec
#
#  ======================================
#  |  Multilevel Ensemble Optimization  |
#  ======================================
#  Optimizing all 294 structures from file "crest_dynamics.trj" ...
#  ----------------------
#  crude pre-optimization
#  ----------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-03 Eh, 0.100E-01 Eh/a0
#  maximum optimization steps: 200
#  |>0.3% |>10.2% |>20.1% |>30.3% |>40.1% |>50.0% |>60.2% |>70.1% |>80.3% |>90.1% |>100.0%
#  done.
# > 294 of 294 structures successfully optimized (100.0% success)
# > Total runtime for 294 optimizations:
#  * wall-time:     0 d,  0 h,  0 min, 38.195 sec
#  *  cpu-time:     0 d,  0 h,  1 min,  1.445 sec
#  * ratio c/w:     1.609 speedup
# > Corresponding to approximately 0.130 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.89314
#  60 structures remain within     5.00 kcal/mol window
#  ----------------------------------
#  optimization with loose thresholds
#  ----------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-04 Eh, 0.400E-02 Eh/a0
#  maximum optimization steps: 200
#  |>1.7% |>10.0% |>20.0% |>30.0% |>40.0% |>50.0% |>60.0% |>71.7% |>80.0% |>91.7% |>100.0%
#  done.
# > 60 of 60 structures successfully optimized (100.0% success)
# > Total runtime for 60 optimizations:
#  * wall-time:     0 d,  0 h,  0 min,  8.709 sec
#  *  cpu-time:     0 d,  0 h,  0 min, 15.438 sec
#  * ratio c/w:     1.773 speedup
# > Corresponding to approximately 0.145 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.89624
#  24 structures remain within     4.00 kcal/mol window
#
# ========================================
#            MTD Simulations done
# ========================================
#  Collecting ensmbles.
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.89624
#  3 structures remain within     2.50 kcal/mol window
#
#
#    ================================================
#    |           Final Geometry Optimization        |
#    ================================================
#  Optimizing all 3 structures from file "crest_rotamers_1.xyz" ...
#  ------------------------------------
#  optimization with regular thresholds
#  ------------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-05 Eh, 0.100E-02 Eh/a0
#  maximum optimization steps: 200
#  |>33.3% |>66.7% |>100.0%
#  done.
# > 3 of 3 structures successfully optimized (100.0% success)
# > Total runtime for 3 optimizations:
#  * wall-time:     0 d,  0 h,  0 min,  0.755 sec
#  *  cpu-time:     0 d,  0 h,  0 min,  0.793 sec
#  * ratio c/w:     1.051 speedup
# > Corresponding to approximately 0.252 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.89675
#  1 structures remain within     2.50 kcal/mol window
#
#
#  --------------------------
#  Final Ensemble Information
#  --------------------------
#  input  file name : crest_rotamers_1.xyz
#  output file name : crest_rotamers_2.xyz
#  number of atoms                :   59
#  number of points on xyz files  :   3
#  RMSD threshold                 :   0.1250
#  Bconst threshold               :   0.0100
#  population threshold           :   0.0500
#  # fragment in coord            :     2
#  # bonds in reference structure :    59
#    => # of C=C bonds :     4
#  number of reliable points      :     3
#  sorting energy window (EWIN)   :    2.5000 / kcal*mol⁻¹
#  reference state Etot           :  -10.896749489999999
#  number of doubles removed by rot/RMSD         :           2
#  total number unique points considered further :           1
#        Erel/kcal        Etot weight/tot  conformer     set   degen     origin
#        1   0.000   -10.89675    1.00000    1.00000       1       1
# T /K                                  :   298.15
# E lowest                              :   -10.89675
# ensemble average energy (kcal)        :    0.000
# ensemble entropy (J/mol K, cal/mol K) :   -0.000   -0.000
# ensemble free energy (kcal/mol)       :    0.000
# population of lowest in %             :  100.000
#  number of unique conformers for further calc            1
#  list of relative energies saved as "crest.energies"
#
#  -----------------
#  Wall Time Summary
#  -----------------
#  CREST runtime (total)               0 d,  0 h,  1 min, 19.552 sec
#  ------------------------------------------------------------------
#  Trial metadynamics (MTD)   ...        0 min,  1.190 sec (  1.496%)
#  Metadynamics (MTD)         ...        0 min, 27.893 sec ( 35.062%)
#  Geometry optimization      ...        0 min, 49.338 sec ( 62.020%)
#  I/O and setup              ...        0 min,  1.131 sec (  1.422%)
#  ------------------------------------------------------------------
#  * wall-time:     0 d,  0 h,  1 min, 19.552 sec
#  *  cpu-time:     0 d,  0 h,  2 min,  4.146 sec
#  * ratio c/w:     1.561 speedup
#  ------------------------------------------------------------------
#  * Total number of energy+grad calls: 28485
#
#  CREST terminated normally.
#
# CREST runtime: 79.6 s
# Return code: 0
#
# RS_CMe2CO2Me: 1 CREST conformers
# RS_CMe2CO2Me: 1 retained
# RS_CMe2CO2Me: 0 torsion duplicates removed
#
# COMPLETED: RS_CMe2CO2Me
# Retained   : 1
# Duplicates : 0
#
#
# ================================================================================
# [23/34] Processing: RS_Cy.xyz
# ================================================================================
#
#
# ================================================================================
# PROCESSING: RS_Cy
# ================================================================================
#
# CREST command:
# /content/crest/crest struc.xyz --cinp constraints.inp --T 2 --gfnff -mquick
#
#
#        ╔════════════════════════════════════════════════╗
#        ║                                                ║
#        ║     ██████╗██████╗ ███████╗███████╗████████╗   ║
#        ║    ██╔════╝██╔══██╗██╔════╝██╔════╝╚══██╔══╝   ║
#        ║    ██║     ██████╔╝█████╗  ███████╗   ██║      ║
#        ║    ██║     ██╔══██╗██╔══╝  ╚════██║   ██║      ║
#        ║    ╚██████╗██║  ██║███████╗███████║   ██║      ║
#        ║     ╚═════╝╚═╝  ╚═╝╚══════╝╚══════╝   ╚═╝      ║
#        ║                                                ║
#        ║    Conformer-Rotamer Ensemble Sampling Tool    ║
#        ║            based on the xTB methods            ║
#        ║                                                ║
#        ╚════════════════════════════════════════════════╝
#         Version 3.0.2, Tue, 16 June 10:18:10, 06/16/2026
#         commit (cfdc301) compiled by 'usr@runnervm1li68'
#
#    Cite work conducted with this code as
#
#    • P.Pracht, F.Bohle, S.Grimme, PCCP, 2020, 22, 7169-7192.
#    • S.Grimme, JCTC, 2019, 15, 2847-2862.
#    • P.Pracht, S.Grimme, C.Bannwarth, F.Bohle, S.Ehlert,
#      G.Feldmann, J.Gorges, M.Müller, T.Neudecker, C.Plett,
#      S.Spicher, P.Steinbach, P.Wesołowski, F.Zeller,
#      J. Chem. Phys., 2024, 160, 114110.
#
#    for works involving QCG cite
#
#    • S.Spicher, C.Plett, P.Pracht, A.Hansen, S.Grimme,
#      JCTC, 2022, 18 (5), 3174-3189.
#    • C.Plett, S. Grimme,
#      Angew. Chem. Int. Ed. 2023, 62, e202214477.
#
#    for works involving MECP screening cite
#
#    • P.Pracht, C.Bannwarth, JCTC, 2022, 18 (10), 6370-6385.
#
#    Original code
#      P.Pracht, S.Grimme, Universität Bonn, MCTC
#    with help from (alphabetical order):
#      C.Bannwarth, F.Bohle, S.Ehlert, G.Feldmann, J.Gorges,
#      S.Grimme, C.Plett, P.Pracht, S.Spicher, P.Steinbach,
#      P.Wesolowski, F.Zeller
#
#    Online documentation is available at
#    https://crest-lab.github.io/crest-docs/
#
#    This program is distributed in the hope that it will be useful,
#    but WITHOUT ANY WARRANTY; without even the implied warranty of
#    MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the
#    GNU Lesser General Public License (LGPL) for more details.
#
#  Command line input:
#  $ /content/crest/crest struc.xyz --cinp constraints.inp --T 2 --gfnff -mquick
#
#   -cinp : constraints.inp
#   --T 2 (CPUs/Threads selected)
#   --gfnff : Use of GFN-FF requested.
#   -mquick  : very crude quick-mode (no NORMMD, no GC, crude opt.)
#
#  <constraints.inp> file present.
#  content of the constraining file (sorted):
# > $constrain
# >   distance: 17, 22, auto
# >   force constant=1.0
# Parsing xtb-type input file constraints.inp to set up calculators ...
# Parsing xtb-type input file bondlengths to set up calculators ...
#
# > Setting up backup calculator ... done.
#  ----------------
#  Calculation info
#  ----------------
# > User-defined calculation level:
#  : GFN-FF calculation via GFNFF lib
#  :   Molecular charge    : 0
#
# > User-defined constraints:
#   # bond constraints    : 78
#
#
#  -----------------------------
#  Initial Geometry Optimization
#  -----------------------------
#  Geometry successfully optimized.
#
#           ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
#           │              CREST iMTD-GC SAMPLING             │
#           ┕━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
#
#  Input structure:
#   60
#
#  H          4.8666167450       -1.0653879214       -0.2518480844
#  O          4.3857911931       -0.8954421460       -1.0851179453
#  C          3.0383344950       -0.9414627819       -0.8783347853
#  C          2.5113705507       -1.4383464016        0.3317875920
#  C          1.1524695882       -1.4654029292        0.5549908241
#  C          0.2275844626       -0.9883609767       -0.4263923364
#  C          0.7650433509       -0.4934447187       -1.6653310079
#  C          2.1476057958       -0.4763329993       -1.8767271681
#  Cl         3.6095049469       -1.9963750106        1.5453532175
#  Cl         0.5107426650       -2.0347808316        2.0390966526
#  C          2.6898790972        0.0216333989       -3.0598684874
#  N          3.1489014357        0.4409876298       -4.0426646977
#  C         -0.1180795525       -0.0393765087       -2.6306405353
#  N         -0.8645737407        0.3253130513       -3.4479016877
#  O         -0.9863086376       -1.0050276460       -0.1950435803
#  H         -1.8634123180        0.7304160135       -0.4622551481
#  O         -2.3154817434        1.5990829356       -0.6327819286
#  C         -3.7284848164        1.4666737208       -0.4369013110
#  C         -4.1680827272        2.3114250054        0.7773780414
#  C         -3.5383117545        1.8456598068        2.0367949628
#  C         -2.1990436621        1.8148158172        2.2034046454
#  C         -1.2939258425        2.3102685562        1.2406907704
#  C          0.0981098490        2.0998477969        1.2557289906
#  C          0.8938292929        2.6032739926        0.1990833541
#  C          0.7500767296        1.3642008892        2.2742659346
#  C          2.2377507673        2.3664536215        0.1477029753
#  C          2.0943107648        1.1363138536        2.2216877133
#  C          2.8765292831        1.6112809781        1.1506394927
#  O          4.2184890868        1.2759874952        1.1453556864
#  C          4.9714557870        1.8913968587        0.1227008986
#  H         -5.2598322687        2.3127752304        0.8652098068
#  H         -3.8910901461        3.3571124359        0.6051725208
#  H         -4.1764360776        1.4404024784        2.8069356913
#  H         -1.7979805947        1.3681021545        3.0978391334
#  H         -1.6735284415        2.9648106326        0.4762449732
#  H          0.4111406380        3.1601229096       -0.5866224865
#  H          0.1753578696        0.9709148307        3.0940306999
#  H          2.8156001462        2.7415882406       -0.6791520920
#  H          2.5907791173        0.5691691388        2.9911091536
#  H          6.0196658512        1.6189859148        0.2468464043
#  H          4.6314148248        1.5446591598       -0.8540460878
#  H          4.8789579958        2.9757516407        0.1947279966
#  H         -4.1950990119        1.8781059557       -1.3457785508
#  C         -4.1312147698       -0.0212082637       -0.3324521618
#  C         -5.6327436536       -0.2485528658       -0.0409955462
#  C         -3.7337796014       -0.8029763763       -1.6049935721
#  H         -3.5648357353       -0.4465236716        0.5099541602
#  C         -5.9454607414       -1.7487155614        0.1168795902
#  H         -6.2206951664        0.1699477656       -0.8656969425
#  H         -5.9422071590        0.3040165878        0.8541210952
#  C         -4.0160427910       -2.3052332253       -1.4396464019
#  H         -4.3075851483       -0.4105758068       -2.4522941407
#  H         -2.6831037912       -0.6237716575       -1.8607737082
#  C         -5.5024553695       -2.5496710557       -1.1219123391
#  H         -7.0149462985       -1.9022786266        0.3162973777
#  H         -5.4257360131       -2.1346639048        1.0027849046
#  H         -3.7073379936       -2.8621551764       -2.3349302558
#  H         -3.3985750473       -2.6987288670       -0.6223924876
#  H         -5.6976319293       -3.6218799715       -0.9815326306
#  H         -6.1117754735       -2.2519204707       -1.9842460236
#
#  ------------------------------------------------
#  Generating MTD length from a flexibility measure
#  ------------------------------------------------
#  Calculating GFN0-xTB WBOs   ... done.
#  Calculating NCI flexibility ... done.
#      covalent flexibility measure :   0.216
#  non-covalent flexibility measure :   0.507
#  flexibility measure :   0.226
#  t(MTD) / ps    :     5.0
#  Σ(t(MTD)) / ps :    30.0 (6 MTDs)
#
#  -----------------------------------
#  Starting trial MTD to test settings
#  -----------------------------------
#  Trial MTD 1 runtime (1.0 ps) ...        0 min,  1.774 sec
#  Estimated runtime for one MTD (5.0 ps) on a single thread: 9 sec
#  Estimated runtime for a batch of 6 MTDs on 2 threads: 27 sec
#
# ********************************************************************************
# **                    N E W   I T E R A T I O N  C Y C L E                    **
# ********************************************************************************
#
#  ------------------------------
#  Meta-Dynamics Iteration 1
#  ------------------------------
#  list of applied metadynamics Vbias parameters:
# $metadyn    0.12000   1.000
# $metadyn    0.06000   1.000
# $metadyn    0.12000   0.500
# $metadyn    0.06000   0.500
# $metadyn    0.12000   0.250
# $metadyn    0.06000   0.250
#
#   ::::::::::::: starting MTD    1 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1200 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
#   ::::::::::::: starting MTD    4 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0600 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
# *MTD   1 completed successfully ...        0 min,  7.754 sec
#   ::::::::::::: starting MTD    2 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0600 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
# *MTD   4 completed successfully ...        0 min,  8.412 sec
#   ::::::::::::: starting MTD    5 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1200 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   5 completed successfully ...        0 min, 10.139 sec
#   ::::::::::::: starting MTD    6 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0600 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   2 completed successfully ...        0 min, 11.570 sec
#   ::::::::::::: starting MTD    3 :::::::::::::
#   |   MD simulation time   :     5.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1200 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
# *MTD   6 completed successfully ...        0 min,  7.888 sec
# *MTD   3 completed successfully ...        0 min,  7.681 sec
#
#  ======================================
#  |  Multilevel Ensemble Optimization  |
#  ======================================
#  Optimizing all 294 structures from file "crest_dynamics.trj" ...
#  ----------------------
#  crude pre-optimization
#  ----------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-03 Eh, 0.100E-01 Eh/a0
#  maximum optimization steps: 200
#  |>0.3% |>10.2% |>20.1% |>30.3% |>40.1% |>50.0% |>60.2% |>70.1% |>80.3% |>90.1% |>100.0%
#  done.
# > 294 of 294 structures successfully optimized (100.0% success)
# > Total runtime for 294 optimizations:
#  * wall-time:     0 d,  0 h,  0 min, 42.940 sec
#  *  cpu-time:     0 d,  0 h,  1 min,  5.722 sec
#  * ratio c/w:     1.531 speedup
# > Corresponding to approximately 0.146 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.95006
#  64 structures remain within     5.00 kcal/mol window
#  ----------------------------------
#  optimization with loose thresholds
#  ----------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-04 Eh, 0.400E-02 Eh/a0
#  maximum optimization steps: 200
#  |>1.6% |>10.9% |>20.3% |>31.2% |>40.6% |>50.0% |>60.9% |>70.3% |>81.2% |>90.6% |>100.0%
#  done.
# > 64 of 64 structures successfully optimized (100.0% success)
# > Total runtime for 64 optimizations:
#  * wall-time:     0 d,  0 h,  0 min,  8.178 sec
#  *  cpu-time:     0 d,  0 h,  0 min, 15.474 sec
#  * ratio c/w:     1.892 speedup
# > Corresponding to approximately 0.128 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.95186
#  27 structures remain within     4.00 kcal/mol window
#
# ========================================
#            MTD Simulations done
# ========================================
#  Collecting ensmbles.
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.95186
#  17 structures remain within     2.50 kcal/mol window
#
#
#    ================================================
#    |           Final Geometry Optimization        |
#    ================================================
#  Optimizing all 17 structures from file "crest_rotamers_1.xyz" ...
#  ------------------------------------
#  optimization with regular thresholds
#  ------------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-05 Eh, 0.100E-02 Eh/a0
#  maximum optimization steps: 200
#  |>5.9% |>11.8% |>23.5% |>35.3% |>41.2% |>52.9% |>64.7% |>70.6% |>82.4% |>94.1% |>100.0%
#  done.
# > 17 of 17 structures successfully optimized (100.0% success)
# > Total runtime for 17 optimizations:
#  * wall-time:     0 d,  0 h,  0 min,  3.561 sec
#  *  cpu-time:     0 d,  0 h,  0 min,  4.027 sec
#  * ratio c/w:     1.131 speedup
# > Corresponding to approximately 0.209 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.95189
#  7 structures remain within     2.50 kcal/mol window
#
#
#  --------------------------
#  Final Ensemble Information
#  --------------------------
#  input  file name : crest_rotamers_1.xyz
#  output file name : crest_rotamers_2.xyz
#  number of atoms                :   60
#  number of points on xyz files  :   17
#  RMSD threshold                 :   0.1250
#  Bconst threshold               :   0.0100
#  population threshold           :   0.0500
#  # fragment in coord            :     2
#  # bonds in reference structure :    61
#    => # of C=C bonds :     4
#  number of reliable points      :    17
#  sorting energy window (EWIN)   :    2.5000 / kcal*mol⁻¹
#  reference state Etot           :  -10.951894619999999
#  number of doubles removed by rot/RMSD         :          10
#  total number unique points considered further :           7
#        Erel/kcal        Etot weight/tot  conformer     set   degen     origin
#        1   0.000   -10.95189    0.54045    0.54045       1       1
#        2   0.748   -10.95070    0.15304    0.30150       2       2
#        3   0.766   -10.95067    0.14846
#        4   1.426   -10.94962    0.04882    0.14517       3       3
#        5   1.432   -10.94961    0.04834
#        6   1.436   -10.94961    0.04801
#        7   2.216   -10.94836    0.01288    0.01288       4       1
# T /K                                  :   298.15
# E lowest                              :   -10.95189
# ensemble average energy (kcal)        :    0.465
# ensemble entropy (J/mol K, cal/mol K) :   11.630    2.780
# ensemble free energy (kcal/mol)       :   -0.829
# population of lowest in %             :   54.045
#  number of unique conformers for further calc            4
#  list of relative energies saved as "crest.energies"
#
#  -----------------
#  Wall Time Summary
#  -----------------
#  CREST runtime (total)               0 d,  0 h,  1 min, 26.377 sec
#  ------------------------------------------------------------------
#  Trial metadynamics (MTD)   ...        0 min,  1.787 sec (  2.069%)
#  Metadynamics (MTD)         ...        0 min, 27.084 sec ( 31.356%)
#  Geometry optimization      ...        0 min, 55.988 sec ( 64.818%)
#  I/O and setup              ...        0 min,  1.518 sec (  1.757%)
#  ------------------------------------------------------------------
#  * wall-time:     0 d,  0 h,  1 min, 26.377 sec
#  *  cpu-time:     0 d,  0 h,  2 min, 13.594 sec
#  * ratio c/w:     1.547 speedup
#  ------------------------------------------------------------------
#  * Total number of energy+grad calls: 28508
#
#  CREST terminated normally.
#
# CREST runtime: 86.4 s
# Return code: 0
#
# RS_Cy: 4 CREST conformers
# RS_Cy: 3 retained
# RS_Cy: 1 torsion duplicates removed
#
# COMPLETED: RS_Cy
# Retained   : 3
# Duplicates : 1
#
#
# ================================================================================
# [24/34] Processing: RS_Et.xyz
# ================================================================================
#
#
# ================================================================================
# PROCESSING: RS_Et
# ================================================================================
#
# CREST command:
# /content/crest/crest struc.xyz --cinp constraints.inp --T 2 --gfnff -mquick
#
#
#        ╔════════════════════════════════════════════════╗
#        ║                                                ║
#        ║     ██████╗██████╗ ███████╗███████╗████████╗   ║
#        ║    ██╔════╝██╔══██╗██╔════╝██╔════╝╚══██╔══╝   ║
#        ║    ██║     ██████╔╝█████╗  ███████╗   ██║      ║
#        ║    ██║     ██╔══██╗██╔══╝  ╚════██║   ██║      ║
#        ║    ╚██████╗██║  ██║███████╗███████║   ██║      ║
#        ║     ╚═════╝╚═╝  ╚═╝╚══════╝╚══════╝   ╚═╝      ║
#        ║                                                ║
#        ║    Conformer-Rotamer Ensemble Sampling Tool    ║
#        ║            based on the xTB methods            ║
#        ║                                                ║
#        ╚════════════════════════════════════════════════╝
#         Version 3.0.2, Tue, 16 June 10:18:10, 06/16/2026
#         commit (cfdc301) compiled by 'usr@runnervm1li68'
#
#    Cite work conducted with this code as
#
#    • P.Pracht, F.Bohle, S.Grimme, PCCP, 2020, 22, 7169-7192.
#    • S.Grimme, JCTC, 2019, 15, 2847-2862.
#    • P.Pracht, S.Grimme, C.Bannwarth, F.Bohle, S.Ehlert,
#      G.Feldmann, J.Gorges, M.Müller, T.Neudecker, C.Plett,
#      S.Spicher, P.Steinbach, P.Wesołowski, F.Zeller,
#      J. Chem. Phys., 2024, 160, 114110.
#
#    for works involving QCG cite
#
#    • S.Spicher, C.Plett, P.Pracht, A.Hansen, S.Grimme,
#      JCTC, 2022, 18 (5), 3174-3189.
#    • C.Plett, S. Grimme,
#      Angew. Chem. Int. Ed. 2023, 62, e202214477.
#
#    for works involving MECP screening cite
#
#    • P.Pracht, C.Bannwarth, JCTC, 2022, 18 (10), 6370-6385.
#
#    Original code
#      P.Pracht, S.Grimme, Universität Bonn, MCTC
#    with help from (alphabetical order):
#      C.Bannwarth, F.Bohle, S.Ehlert, G.Feldmann, J.Gorges,
#      S.Grimme, C.Plett, P.Pracht, S.Spicher, P.Steinbach,
#      P.Wesolowski, F.Zeller
#
#    Online documentation is available at
#    https://crest-lab.github.io/crest-docs/
#
#    This program is distributed in the hope that it will be useful,
#    but WITHOUT ANY WARRANTY; without even the implied warranty of
#    MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the
#    GNU Lesser General Public License (LGPL) for more details.
#
#  Command line input:
#  $ /content/crest/crest struc.xyz --cinp constraints.inp --T 2 --gfnff -mquick
#
#   -cinp : constraints.inp
#   --T 2 (CPUs/Threads selected)
#   --gfnff : Use of GFN-FF requested.
#   -mquick  : very crude quick-mode (no NORMMD, no GC, crude opt.)
#
#  <constraints.inp> file present.
#  content of the constraining file (sorted):
# > $constrain
# >   distance: 17, 22, auto
# >   force constant=1.0
# Parsing xtb-type input file constraints.inp to set up calculators ...
# Parsing xtb-type input file bondlengths to set up calculators ...
#
# > Setting up backup calculator ... done.
#  ----------------
#  Calculation info
#  ----------------
# > User-defined calculation level:
#  : GFN-FF calculation via GFNFF lib
#  :   Molecular charge    : 0
#
# > User-defined constraints:
#   # bond constraints    : 63
#
#
#  -----------------------------
#  Initial Geometry Optimization
#  -----------------------------
#  Geometry successfully optimized.
#
#           ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
#           │              CREST iMTD-GC SAMPLING             │
#           ┕━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
#
#  Input structure:
#   50
#
#  H          4.4375669853       -1.6216984139       -0.0607062971
#  O          4.3117567845       -0.8129752053       -0.5949132096
#  C          2.9873374304       -0.5900631113       -0.8308184831
#  C          2.0144100080       -1.5019205792       -0.3777966457
#  C          0.6823311150       -1.3112017274       -0.6532942508
#  C          0.2392396661       -0.1842481773       -1.4110573993
#  C          1.2257968064        0.7716422711       -1.8373469692
#  C          2.5770902085        0.5619108971       -1.5461273946
#  Cl         2.5092287266       -2.8711973465        0.5423096778
#  Cl        -0.4911072969       -2.4177804345       -0.0799627665
#  C          3.5515150774        1.4713132842       -1.9564067664
#  N          4.3632581719        2.2268352820       -2.3072763383
#  C          0.7999948795        1.8902005698       -2.5354031095
#  N          0.4438622279        2.8334257214       -3.1190659598
#  O         -0.9594687731       -0.0514089472       -1.6823051472
#  H         -2.4368666139       -0.3829863331       -0.4922379476
#  O         -3.1681125847       -0.5509137320        0.1622338521
#  C         -4.4593835622       -0.2779554208       -0.3999570247
#  C         -5.2611432373        0.6516822912        0.5321162572
#  C         -4.6487364488        2.0046467855        0.6122983544
#  C         -3.3786080589        2.2168217294        1.0225289198
#  C         -2.5563408939        1.2040507190        1.5635704867
#  C         -1.1553266292        1.2608785910        1.6751145154
#  C         -0.4577426503        0.2111104023        2.3185609471
#  C         -0.3912459530        2.3066971550        1.1047916958
#  C          0.9059479824        0.2036493335        2.3851580912
#  C          0.9714302185        2.2886186209        1.1656470049
#  C          1.6612510125        1.2371801346        1.7994638810
#  O          3.0428755713        1.2879918266        1.7827960790
#  C          3.6825480269        0.2820517141        2.5344225759
#  H         -6.2994795008        0.7186978828        0.1880123513
#  H         -5.3052890542        0.2024067463        1.5289364197
#  H         -5.2124514335        2.8365249569        0.2192961795
#  H         -2.9612217569        3.2056148650        0.9209316468
#  H         -3.0371872160        0.3163248124        1.9367485041
#  H         -1.0261797685       -0.5949307138        2.7514598426
#  H         -0.8943750518        3.1045876285        0.5873567784
#  H          1.4142162964       -0.6086202704        2.8750681593
#  H          1.5574660255        3.0746556512        0.7191891452
#  H          4.7600567114        0.4363396114        2.4728659733
#  H          3.3744401852        0.3489358331        3.5787739971
#  H          3.4447551232       -0.7024992435        2.1301909392
#  H         -4.3038332152        0.2592417587       -1.3509216981
#  C         -5.1951566018       -1.5856611252       -0.7022995492
#  H         -6.1878759687       -1.3662796540       -1.1140185447
#  H         -5.3727333848       -2.1083548891        0.2441572338
#  C         -4.4040964537       -2.4669237731       -1.6494125020
#  H         -3.4324418734       -2.7225201385       -1.2235769300
#  H         -4.9231852917       -3.4008258475       -1.8748217582
#  H         -4.2144307753       -1.9572662601       -2.5958393138
#
#  ------------------------------------------------
#  Generating MTD length from a flexibility measure
#  ------------------------------------------------
#  Calculating GFN0-xTB WBOs   ... done.
#  Calculating NCI flexibility ... done.
#      covalent flexibility measure :   0.242
#  non-covalent flexibility measure :   0.499
#  flexibility measure :   0.244
#  t(MTD) / ps    :     4.0
#  Σ(t(MTD)) / ps :    24.0 (6 MTDs)
#
#  -----------------------------------
#  Starting trial MTD to test settings
#  -----------------------------------
#  Trial MTD 1 runtime (1.0 ps) ...        0 min,  1.490 sec
#  Estimated runtime for one MTD (4.0 ps) on a single thread: 6 sec
#  Estimated runtime for a batch of 6 MTDs on 2 threads: 18 sec
#
# ********************************************************************************
# **                    N E W   I T E R A T I O N  C Y C L E                    **
# ********************************************************************************
#
#  ------------------------------
#  Meta-Dynamics Iteration 1
#  ------------------------------
#  list of applied metadynamics Vbias parameters:
# $metadyn    0.10000   1.000
# $metadyn    0.05000   1.000
# $metadyn    0.10000   0.500
# $metadyn    0.05000   0.500
# $metadyn    0.10000   0.250
# $metadyn    0.05000   0.250
#
#   ::::::::::::: starting MTD    4 :::::::::::::
#   |   MD simulation time   :     4.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0500 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
#   ::::::::::::: starting MTD    1 :::::::::::::
#   |   MD simulation time   :     4.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1000 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
# *MTD   4 completed successfully ...        0 min,  5.790 sec
#   ::::::::::::: starting MTD    5 :::::::::::::
#   |   MD simulation time   :     4.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1000 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   1 completed successfully ...        0 min,  5.984 sec
#   ::::::::::::: starting MTD    2 :::::::::::::
#   |   MD simulation time   :     4.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0500 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
# *MTD   5 completed successfully ...        0 min,  5.285 sec
#   ::::::::::::: starting MTD    6 :::::::::::::
#   |   MD simulation time   :     4.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0500 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   2 completed successfully ...        0 min,  5.527 sec
#   ::::::::::::: starting MTD    3 :::::::::::::
#   |   MD simulation time   :     4.0 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1000 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
# *MTD   6 completed successfully ...        0 min,  7.591 sec
# *MTD   3 completed successfully ...        0 min,  7.551 sec
#
#  ======================================
#  |  Multilevel Ensemble Optimization  |
#  ======================================
#  Optimizing all 234 structures from file "crest_dynamics.trj" ...
#  ----------------------
#  crude pre-optimization
#  ----------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-03 Eh, 0.100E-01 Eh/a0
#  maximum optimization steps: 200
#  |>0.4% |>10.3% |>20.1% |>30.3% |>40.2% |>50.0% |>60.3% |>70.1% |>80.3% |>90.2% |>100.0%
#  done.
# > 234 of 234 structures successfully optimized (100.0% success)
# > Total runtime for 234 optimizations:
#  * wall-time:     0 d,  0 h,  0 min, 18.043 sec
#  *  cpu-time:     0 d,  0 h,  0 min, 29.148 sec
#  * ratio c/w:     1.615 speedup
# > Corresponding to approximately 0.077 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :    -9.37502
#  40 structures remain within     5.00 kcal/mol window
#  ----------------------------------
#  optimization with loose thresholds
#  ----------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-04 Eh, 0.400E-02 Eh/a0
#  maximum optimization steps: 200
#  |>2.5% |>10.0% |>20.0% |>30.0% |>40.0% |>50.0% |>60.0% |>72.5% |>80.0% |>92.5% |>100.0%
#  done.
# > 40 of 40 structures successfully optimized (100.0% success)
# > Total runtime for 40 optimizations:
#  * wall-time:     0 d,  0 h,  0 min,  2.788 sec
#  *  cpu-time:     0 d,  0 h,  0 min,  5.162 sec
#  * ratio c/w:     1.851 speedup
# > Corresponding to approximately 0.070 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :    -9.37591
#  23 structures remain within     4.00 kcal/mol window
#
# ========================================
#            MTD Simulations done
# ========================================
#  Collecting ensmbles.
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :    -9.37591
#  21 structures remain within     2.50 kcal/mol window
#
#
#    ================================================
#    |           Final Geometry Optimization        |
#    ================================================
#  Optimizing all 21 structures from file "crest_rotamers_1.xyz" ...
#  ------------------------------------
#  optimization with regular thresholds
#  ------------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-05 Eh, 0.100E-02 Eh/a0
#  maximum optimization steps: 200
#  |>4.8% |>14.3% |>23.8% |>33.3% |>42.9% |>52.4% |>61.9% |>71.4% |>81.0% |>90.5% |>100.0%
#  done.
# > 21 of 21 structures successfully optimized (100.0% success)
# > Total runtime for 21 optimizations:
#  * wall-time:     0 d,  0 h,  0 min,  1.532 sec
#  *  cpu-time:     0 d,  0 h,  0 min,  2.823 sec
#  * ratio c/w:     1.842 speedup
# > Corresponding to approximately 0.073 sec per processed structure
#
# ...
#  C         -0.1122436181       -0.0642120726       -2.5551992959
#  C         -1.4960250060        2.0373140001       -1.3666772993
#  C         -1.4766825376       -0.0698159516       -2.5488490498
#  C         -2.2104522425        0.9695354551       -1.9429604284
#  O         -3.5887784153        0.8514563289       -1.9280415030
#  C         -4.2683247759        1.9912982670       -1.4475205847
#  H          5.9246443947        0.6856605261       -1.1232517297
#  H          4.7605358112        1.9011615911       -1.5599347582
#  H          4.7885669536       -0.8199448082       -2.5698583592
#  H          2.4410463465       -0.7417052256       -3.0396811938
#  H          2.4668471560        1.8986094042       -1.4746529780
#  H          0.4059933807        2.8601668306       -0.9096396615
#  H          0.4228884075       -0.8808984182       -3.0072802605
#  H         -2.0355125056        2.8404898275       -0.8965035696
#  H         -2.0301055861       -0.8797830822       -2.9944471878
#  H         -5.3414156245        1.8320068454       -1.5578754489
#  H         -4.0422164758        2.1452469412       -0.3916695239
#  H         -3.9818423052        2.8681462280       -2.0300874952
#  H          4.6863482031        1.6740677504        0.8265993668
#  C          4.5495215500       -0.4479770100        1.0850802855
#  C          6.0693761445       -0.6179222497        1.2465852735
#  C          3.9748718628       -1.6995159749        0.4082319848
#  C          3.9222715171       -0.2867976178        2.4796854526
#  H          6.2960451089       -1.4603959858        1.9006696289
#  H          6.5531894030       -0.8085011926        0.2891831461
#  H          6.5184231177        0.2746067504        1.6829787882
#  H          2.9150938454       -1.5876701568        0.1902918873
#  H          4.4882102566       -1.9131504156       -0.5273995217
#  H          4.0903637952       -2.5727619834        1.0500109419
#  H          4.1410563481       -1.1508108643        3.1069833874
#  H          4.3094024675        0.6001055442        2.9814040818
#  H          2.8391092378       -0.1890801160        2.4217855578
#
#  ------------------------------------------------
#  Generating MTD length from a flexibility measure
#  ------------------------------------------------
#  Calculating GFN0-xTB WBOs   ... done.
#  Calculating NCI flexibility ... done.
#      covalent flexibility measure :   0.209
#  non-covalent flexibility measure :   0.498
#  flexibility measure :   0.218
#  t(MTD) / ps    :     4.5
#  Σ(t(MTD)) / ps :    27.0 (6 MTDs)
#
#  -----------------------------------
#  Starting trial MTD to test settings
#  -----------------------------------
#  Trial MTD 1 runtime (1.0 ps) ...        0 min,  1.601 sec
#  Estimated runtime for one MTD (4.5 ps) on a single thread: 7 sec
#  Estimated runtime for a batch of 6 MTDs on 2 threads: 22 sec
#
# ********************************************************************************
# **                    N E W   I T E R A T I O N  C Y C L E                    **
# ********************************************************************************
#
#  ------------------------------
#  Meta-Dynamics Iteration 1
#  ------------------------------
#  list of applied metadynamics Vbias parameters:
# $metadyn    0.11200   1.000
# $metadyn    0.05600   1.000
# $metadyn    0.11200   0.500
# $metadyn    0.05600   0.500
# $metadyn    0.11200   0.250
# $metadyn    0.05600   0.250
#
#   ::::::::::::: starting MTD    4 :::::::::::::
#   |   MD simulation time   :     4.5 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0560 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
#   ::::::::::::: starting MTD    1 :::::::::::::
#   |   MD simulation time   :     4.5 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1120 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
# *MTD   1 completed successfully ...        0 min,  6.250 sec
#   ::::::::::::: starting MTD    2 :::::::::::::
#   |   MD simulation time   :     4.5 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0560 Eh       |
#   |   Vbias exponent (α)   :  1.0000 bohr⁻²   |
# *MTD   4 completed successfully ...        0 min,  6.613 sec
#   ::::::::::::: starting MTD    5 :::::::::::::
#   |   MD simulation time   :     4.5 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1120 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   5 completed successfully ...        0 min,  7.857 sec
#   ::::::::::::: starting MTD    6 :::::::::::::
#   |   MD simulation time   :     4.5 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.0560 Eh       |
#   |   Vbias exponent (α)   :  0.2500 bohr⁻²   |
# *MTD   2 completed successfully ...        0 min,  8.862 sec
#   ::::::::::::: starting MTD    3 :::::::::::::
#   |   MD simulation time   :     4.5 ps       |
#   |   target T             :   300.0 K        |
#   |   timestep dt          :     1.5 fs       |
#   |   dump interval(trj)   :   100.0 fs       |
#   |   SHAKE algorithm      : true (all bonds) |
#   |   dump interval(Vbias) :    1.00 ps       |
#   |   Vbias prefactor (k)  :  0.1120 Eh       |
#   |   Vbias exponent (α)   :  0.5000 bohr⁻²   |
# *MTD   3 completed successfully ...        0 min,  7.079 sec
# *MTD   6 completed successfully ...        0 min,  7.807 sec
#
#  ======================================
#  |  Multilevel Ensemble Optimization  |
#  ======================================
#  Optimizing all 264 structures from file "crest_dynamics.trj" ...
#  ----------------------
#  crude pre-optimization
#  ----------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-03 Eh, 0.100E-01 Eh/a0
#  maximum optimization steps: 200
#  |>0.4% |>10.2% |>20.1% |>30.3% |>40.2% |>50.0% |>60.2% |>70.1% |>80.3% |>90.2% |>100.0%
#  done.
# > 264 of 264 structures successfully optimized (100.0% success)
# > Total runtime for 264 optimizations:
#  * wall-time:     0 d,  0 h,  0 min, 35.681 sec
#  *  cpu-time:     0 d,  0 h,  0 min, 58.163 sec
#  * ratio c/w:     1.630 speedup
# > Corresponding to approximately 0.135 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.26859
#  83 structures remain within     5.00 kcal/mol window
#  ----------------------------------
#  optimization with loose thresholds
#  ----------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-04 Eh, 0.400E-02 Eh/a0
#  maximum optimization steps: 200
#  |>1.2% |>10.8% |>20.5% |>30.1% |>41.0% |>50.6% |>60.2% |>71.1% |>80.7% |>90.4% |>100.0%
#  done.
# > 83 of 83 structures successfully optimized (100.0% success)
# > Total runtime for 83 optimizations:
#  * wall-time:     0 d,  0 h,  0 min, 10.774 sec
#  *  cpu-time:     0 d,  0 h,  0 min, 15.249 sec
#  * ratio c/w:     1.415 speedup
# > Corresponding to approximately 0.130 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.26921
#  66 structures remain within     4.00 kcal/mol window
#
# ========================================
#            MTD Simulations done
# ========================================
#  Collecting ensmbles.
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.26921
#  63 structures remain within     2.50 kcal/mol window
#
#
#    ================================================
#    |           Final Geometry Optimization        |
#    ================================================
#  Optimizing all 63 structures from file "crest_rotamers_1.xyz" ...
#  ------------------------------------
#  optimization with regular thresholds
#  ------------------------------------
#  Optimization engine: ANCOPT
#  Hessian update type: BFGS
#  E/G convergence criteria:  0.500E-05 Eh, 0.100E-02 Eh/a0
#  maximum optimization steps: 200
#  |>1.6% |>11.1% |>20.6% |>30.2% |>41.3% |>50.8% |>60.3% |>71.4% |>81.0% |>90.5% |>100.0%
#  done.
# > 63 of 63 structures successfully optimized (100.0% success)
# > Total runtime for 63 optimizations:
#  * wall-time:     0 d,  0 h,  0 min, 10.763 sec
#  *  cpu-time:     0 d,  0 h,  0 min, 18.295 sec
#  * ratio c/w:     1.700 speedup
# > Corresponding to approximately 0.171 sec per processed structure
#
# CREGEN> running RMSDs ... done.
# CREGEN> E lowest :   -10.27031
#  28 structures remain within     2.50 kcal/mol window
#
#
#  --------------------------
#  Final Ensemble Information
#  --------------------------
#  input  file name : crest_rotamers_1.xyz
#  output file name : crest_rotamers_2.xyz
#  number of atoms                :   56
#  number of points on xyz files  :   63
#  RMSD threshold                 :   0.1250
#  Bconst threshold               :   0.0100
#  population threshold           :   0.0500
#  # fragment in coord            :     2
#  # bonds in reference structure :    56
#    => # of C=C bonds :     4
#  number of reliable points      :    63
#  sorting energy window (EWIN)   :    2.5000 / kcal*mol⁻¹
#  reference state Etot           :  -10.270306260000000
#  number of doubles removed by rot/RMSD         :          35
#  total number unique points considered further :          28
#        Erel/kcal        Etot weight/tot  conformer     set   degen     origin
#        1   0.000   -10.27031    0.15303    0.30476       1       2
#        2   0.005   -10.27030    0.15174
#        3   0.810   -10.26902    0.03904    0.42509       2      11
#        4   0.811   -10.26901    0.03896
#        5   0.811   -10.26901    0.03896
#        6   0.812   -10.26901    0.03893
#        7   0.812   -10.26901    0.03888
#        8   0.814   -10.26901    0.03877
#        9   0.816   -10.26901    0.03864
#       10   0.816   -10.26901    0.03862
#       11   0.822   -10.26900    0.03827
#       12   0.822   -10.26900    0.03827
#       13   0.830   -10.26898    0.03773
#       14   1.069   -10.26860    0.02522    0.04875       3       2
#       15   1.110   -10.26854    0.02353
#       16   1.131   -10.26850    0.02272    0.02272       4       1
#       17   1.237   -10.26834    0.01902    0.07427       5       4
#       18   1.242   -10.26833    0.01885
#       19   1.260   -10.26830    0.01827
#       20   1.265   -10.26829    0.01813
#       21   1.274   -10.26828    0.01786    0.01786       6       1
#       22   1.287   -10.26825    0.01745    0.03473       7       2
#       23   1.294   -10.26824    0.01728
#       24   1.395   -10.26808    0.01457    0.01457       8       1
#       25   1.399   -10.26808    0.01446    0.02871       9       2
#       26   1.408   -10.26806    0.01425
#       27   1.401   -10.26807    0.01440    0.01440      10       1
#       28   1.412   -10.26806    0.01414    0.01414      11       1
# T /K                                  :   298.15
# E lowest                              :   -10.27031
# ensemble average energy (kcal)        :    0.688
# ensemble entropy (J/mol K, cal/mol K) :   25.249    6.035
# ensemble free energy (kcal/mol)       :   -1.799
# population of lowest in %             :   30.476
#  number of unique conformers for further calc           11
#  list of relative energies saved as "crest.energies"
#
#  -----------------
#  Wall Time Summary
#  -----------------
#  CREST runtime (total)               0 d,  0 h,  1 min, 23.992 sec
#  ------------------------------------------------------------------
#  Trial metadynamics (MTD)   ...        0 min,  1.603 sec (  1.909%)
#  Metadynamics (MTD)         ...        0 min, 22.374 sec ( 26.638%)
#  Geometry optimization      ...        0 min, 58.922 sec ( 70.152%)
#  I/O and setup              ...        0 min,  1.093 sec (  1.301%)
#  ------------------------------------------------------------------
#  * wall-time:     0 d,  0 h,  1 min, 23.992 sec
#  *  cpu-time:     0 d,  0 h,  2 min, 11.861 sec
#  * ratio c/w:     1.570 speedup
#  ------------------------------------------------------------------
#  * Total number of energy+grad calls: 27885
#
#  CREST terminated normally.
#
# CREST runtime: 84.0 s
# Return code: 0
#
# RS_tBu: 11 CREST conformers
# RS_tBu: 3 retained
# RS_tBu: 8 torsion duplicates removed
#
# COMPLETED: RS_tBu
# Retained   : 3
# Duplicates : 8
#
#
# ================================================================================
# CREATING FINAL COMBINED RESULTS
# ================================================================================
#             structure       classification  n_retained
# 0           RR_CH2-Ph             Boat (B)           4
# 1      RR_CH2-dioxane             Boat (B)           3
# 2            RR_CH2CN             Boat (B)           4
# 3         RR_CH2CO2Me             Boat (B)           2
# 4        RR_CMe2CO2Me             Boat (B)           2
# 5               RR_Cy             Boat (B)           3
# 6               RR_Et             Boat (B)           2
# 7               RR_Me             Boat (B)           2
# 8       RR_Me-Propane             Boat (B)           1
# 9               RR_Ph             Boat (B)           2
# 10          RR_alkene             Boat (B)           4
# 11          RR_alkyne             Boat (B)           3
# 12           RR_allyl             Boat (B)           2
# 13  RR_dimethyl-allyl             Boat (B)           3
# 14             RR_iPr             Boat (B)           4
# 15             RR_nBu             Boat (B)           2
# 16             RR_tBu             Boat (B)           3
# 17          RS_CH2-Ph             Boat (B)           1
# 18     RS_CH2-dioxane             Boat (B)           2
# 19           RS_CH2CN             Boat (B)           1
# 20        RS_CH2CO2Me             Boat (B)           2
# 21       RS_CMe2CO2Me             Boat (B)           1
# 22              RS_Cy             Boat (B)           3
# 23              RS_Et             Boat (B)           2
# 24              RS_Me             Boat (B)           3
# 25      RS_Me-Propane             Boat (B)           2
# 26              RS_Ph             Boat (B)           3
# 27              RS_Ph  Twist-boat/Skew (S)           1
# 28          RS_alkene             Boat (B)           3
# 29          RS_alkyne             Boat (B)           2
# 30           RS_allyl             Boat (B)           2
# 31           RS_allyl  Twist-boat/Skew (S)           1
# 32  RS_dimethyl-allyl             Boat (B)           2
# 33             RS_iPr             Boat (B)           3
# 34             RS_nBu             Boat (B)           4
# 35             RS_tBu             Boat (B)           3
# ================================================================================
# BATCH FINISHED
# ================================================================================
# Input structures : 34
# Retained rows     : 87
# Duplicate rows    : 121
# Failed structures : 0
# Results folder    : /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results
#
# Main output files:
# 1. /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/ALL_retained_pucker_results.csv
# 2. /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/ALL_torsion_duplicates.csv
# 3. /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/ALL_batch_failures.csv
# 4. /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/SUMMARY_retained_puckers.csv
# 5. /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/INPUT_validation.csv
#
# Done.

# %%
# ============================================================
# FIND ALL XYZ FILES CREATED BY THE CREST RUN
# ============================================================

from pathlib import Path

CREST_RESULTS_FOLDER = Path(
    "/content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results"
)

print("=" * 80)
print("SEARCHING CREST_RESULTS FOR ALL XYZ FILES")
print("=" * 80)

print(f"\nSearching in:")
print(CREST_RESULTS_FOLDER)

if not CREST_RESULTS_FOLDER.exists():
    print("\nERROR: CREST_results folder does not exist!")
else:

    xyz_files = sorted(
        CREST_RESULTS_FOLDER.rglob("*.xyz")
    )

    print(f"\nTotal XYZ files found: {len(xyz_files)}")

    if len(xyz_files) == 0:

        print("\nNO XYZ FILES FOUND.")

    else:

        print("\nXYZ files found:")
        print("-" * 80)

        for f in xyz_files:
            print(f)

        print("\n" + "=" * 80)
        print("XYZ FILE NAME SUMMARY")
        print("=" * 80)

        from collections import Counter

        counts = Counter(
            f.name for f in xyz_files
        )

        for name, count in counts.items():
            print(f"{name:40s} : {count}")
# Out:
# ================================================================================
# SEARCHING CREST_RESULTS FOR ALL XYZ FILES
# ================================================================================
#
# Searching in:
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results
#
# Total XYZ files found: 155
#
# XYZ files found:
# --------------------------------------------------------------------------------
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-Ph_CREST_conformations/RR_CH2-Ph_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-Ph_CREST_conformations/RR_CH2-Ph_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-Ph_CREST_conformations/RR_CH2-Ph_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-Ph_CREST_conformations/RR_CH2-Ph_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-Ph_CREST_conformations/RR_CH2-Ph_retained_004.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-Ph_CREST_conformations/RR_CH2-Ph_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-dioxane_CREST_conformations/RR_CH2-dioxane_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-dioxane_CREST_conformations/RR_CH2-dioxane_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-dioxane_CREST_conformations/RR_CH2-dioxane_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-dioxane_CREST_conformations/RR_CH2-dioxane_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2-dioxane_CREST_conformations/RR_CH2-dioxane_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CN_CREST_conformations/RR_CH2CN_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CN_CREST_conformations/RR_CH2CN_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CN_CREST_conformations/RR_CH2CN_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CN_CREST_conformations/RR_CH2CN_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CN_CREST_conformations/RR_CH2CN_retained_004.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CN_CREST_conformations/RR_CH2CN_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CO2Me_CREST_conformations/RR_CH2CO2Me_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CO2Me_CREST_conformations/RR_CH2CO2Me_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CO2Me_CREST_conformations/RR_CH2CO2Me_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CH2CO2Me_CREST_conformations/RR_CH2CO2Me_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CMe2CO2Me_CREST_conformations/RR_CMe2CO2Me_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CMe2CO2Me_CREST_conformations/RR_CMe2CO2Me_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CMe2CO2Me_CREST_conformations/RR_CMe2CO2Me_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_CMe2CO2Me_CREST_conformations/RR_CMe2CO2Me_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Cy_CREST_conformations/RR_Cy_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Cy_CREST_conformations/RR_Cy_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Cy_CREST_conformations/RR_Cy_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Cy_CREST_conformations/RR_Cy_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Cy_CREST_conformations/RR_Cy_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Et_CREST_conformations/RR_Et_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Et_CREST_conformations/RR_Et_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Et_CREST_conformations/RR_Et_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Et_CREST_conformations/RR_Et_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Me-Propane_CREST_conformations/RR_Me-Propane_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Me-Propane_CREST_conformations/RR_Me-Propane_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Me-Propane_CREST_conformations/RR_Me-Propane_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Me_CREST_conformations/RR_Me_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Me_CREST_conformations/RR_Me_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Me_CREST_conformations/RR_Me_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Me_CREST_conformations/RR_Me_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Ph_CREST_conformations/RR_Ph_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Ph_CREST_conformations/RR_Ph_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Ph_CREST_conformations/RR_Ph_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_Ph_CREST_conformations/RR_Ph_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkene_CREST_conformations/RR_alkene_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkene_CREST_conformations/RR_alkene_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkene_CREST_conformations/RR_alkene_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkene_CREST_conformations/RR_alkene_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkene_CREST_conformations/RR_alkene_retained_004.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkene_CREST_conformations/RR_alkene_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkyne_CREST_conformations/RR_alkyne_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkyne_CREST_conformations/RR_alkyne_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkyne_CREST_conformations/RR_alkyne_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkyne_CREST_conformations/RR_alkyne_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_alkyne_CREST_conformations/RR_alkyne_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_allyl_CREST_conformations/RR_allyl_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_allyl_CREST_conformations/RR_allyl_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_allyl_CREST_conformations/RR_allyl_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_allyl_CREST_conformations/RR_allyl_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_dimethyl-allyl_CREST_conformations/RR_dimethyl-allyl_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_dimethyl-allyl_CREST_conformations/RR_dimethyl-allyl_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_dimethyl-allyl_CREST_conformations/RR_dimethyl-allyl_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_dimethyl-allyl_CREST_conformations/RR_dimethyl-allyl_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_dimethyl-allyl_CREST_conformations/RR_dimethyl-allyl_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_iPr_CREST_conformations/RR_iPr_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_iPr_CREST_conformations/RR_iPr_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_iPr_CREST_conformations/RR_iPr_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_iPr_CREST_conformations/RR_iPr_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_iPr_CREST_conformations/RR_iPr_retained_004.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_iPr_CREST_conformations/RR_iPr_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_nBu_CREST_conformations/RR_nBu_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_nBu_CREST_conformations/RR_nBu_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_nBu_CREST_conformations/RR_nBu_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_nBu_CREST_conformations/RR_nBu_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_tBu_CREST_conformations/RR_tBu_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_tBu_CREST_conformations/RR_tBu_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_tBu_CREST_conformations/RR_tBu_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_tBu_CREST_conformations/RR_tBu_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RR_tBu_CREST_conformations/RR_tBu_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2-Ph_CREST_conformations/RS_CH2-Ph_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2-Ph_CREST_conformations/RS_CH2-Ph_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2-Ph_CREST_conformations/RS_CH2-Ph_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2-dioxane_CREST_conformations/RS_CH2-dioxane_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2-dioxane_CREST_conformations/RS_CH2-dioxane_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2-dioxane_CREST_conformations/RS_CH2-dioxane_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2-dioxane_CREST_conformations/RS_CH2-dioxane_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2CN_CREST_conformations/RS_CH2CN_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2CN_CREST_conformations/RS_CH2CN_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2CN_CREST_conformations/RS_CH2CN_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2CO2Me_CREST_conformations/RS_CH2CO2Me_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2CO2Me_CREST_conformations/RS_CH2CO2Me_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2CO2Me_CREST_conformations/RS_CH2CO2Me_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CH2CO2Me_CREST_conformations/RS_CH2CO2Me_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CMe2CO2Me_CREST_conformations/RS_CMe2CO2Me_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CMe2CO2Me_CREST_conformations/RS_CMe2CO2Me_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_CMe2CO2Me_CREST_conformations/RS_CMe2CO2Me_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Cy_CREST_conformations/RS_Cy_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Cy_CREST_conformations/RS_Cy_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Cy_CREST_conformations/RS_Cy_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Cy_CREST_conformations/RS_Cy_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Cy_CREST_conformations/RS_Cy_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Et_CREST_conformations/RS_Et_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Et_CREST_conformations/RS_Et_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Et_CREST_conformations/RS_Et_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Et_CREST_conformations/RS_Et_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me-Propane_CREST_conformations/RS_Me-Propane_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me-Propane_CREST_conformations/RS_Me-Propane_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me-Propane_CREST_conformations/RS_Me-Propane_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me-Propane_CREST_conformations/RS_Me-Propane_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me_CREST_conformations/RS_Me_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me_CREST_conformations/RS_Me_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me_CREST_conformations/RS_Me_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me_CREST_conformations/RS_Me_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Me_CREST_conformations/RS_Me_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Ph_CREST_conformations/RS_Ph_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Ph_CREST_conformations/RS_Ph_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Ph_CREST_conformations/RS_Ph_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Ph_CREST_conformations/RS_Ph_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Ph_CREST_conformations/RS_Ph_retained_004.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_Ph_CREST_conformations/RS_Ph_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkene_CREST_conformations/RS_alkene_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkene_CREST_conformations/RS_alkene_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkene_CREST_conformations/RS_alkene_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkene_CREST_conformations/RS_alkene_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkene_CREST_conformations/RS_alkene_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkyne_CREST_conformations/RS_alkyne_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkyne_CREST_conformations/RS_alkyne_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkyne_CREST_conformations/RS_alkyne_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_alkyne_CREST_conformations/RS_alkyne_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_allyl_CREST_conformations/RS_allyl_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_allyl_CREST_conformations/RS_allyl_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_allyl_CREST_conformations/RS_allyl_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_allyl_CREST_conformations/RS_allyl_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_allyl_CREST_conformations/RS_allyl_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_dimethyl-allyl_CREST_conformations/RS_dimethyl-allyl_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_dimethyl-allyl_CREST_conformations/RS_dimethyl-allyl_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_dimethyl-allyl_CREST_conformations/RS_dimethyl-allyl_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_dimethyl-allyl_CREST_conformations/RS_dimethyl-allyl_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_iPr_CREST_conformations/RS_iPr_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_iPr_CREST_conformations/RS_iPr_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_iPr_CREST_conformations/RS_iPr_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_iPr_CREST_conformations/RS_iPr_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_iPr_CREST_conformations/RS_iPr_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_nBu_CREST_conformations/RS_nBu_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_nBu_CREST_conformations/RS_nBu_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_nBu_CREST_conformations/RS_nBu_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_nBu_CREST_conformations/RS_nBu_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_nBu_CREST_conformations/RS_nBu_retained_004.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_nBu_CREST_conformations/RS_nBu_retained_ensemble.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_tBu_CREST_conformations/RS_tBu_raw_crest_conformers.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_tBu_CREST_conformations/RS_tBu_retained_001.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_tBu_CREST_conformations/RS_tBu_retained_002.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_tBu_CREST_conformations/RS_tBu_retained_003.xyz
# /content/drive/MyDrive/Cycloetherification_xyz_files/CREST_results/RS_tBu_CREST_conformations/RS_tBu_retained_ensemble.xyz
#
# ================================================================================
# XYZ FILE NAME SUMMARY
# ================================================================================
# RR_CH2-Ph_raw_crest_conformers.xyz       : 1
# RR_CH2-Ph_retained_001.xyz               : 1
# RR_CH2-Ph_retained_002.xyz               : 1
# RR_CH2-Ph_retained_003.xyz               : 1
# RR_CH2-Ph_retained_004.xyz               : 1
# RR_CH2-Ph_retained_ensemble.xyz          : 1
# RR_CH2-dioxane_raw_crest_conformers.xyz  : 1
# RR_CH2-dioxane_retained_001.xyz          : 1
# RR_CH2-dioxane_retained_002.xyz          : 1
# RR_CH2-dioxane_retained_003.xyz          : 1
# RR_CH2-dioxane_retained_ensemble.xyz     : 1
# RR_CH2CN_raw_crest_conformers.xyz        : 1
# RR_CH2CN_retained_001.xyz                : 1
# RR_CH2CN_retained_002.xyz                : 1
# RR_CH2CN_retained_003.xyz                : 1
# RR_CH2CN_retained_004.xyz                : 1
# RR_CH2CN_retained_ensemble.xyz           : 1
# RR_CH2CO2Me_raw_crest_conformers.xyz     : 1
# RR_CH2CO2Me_retained_001.xyz             : 1
# RR_CH2CO2Me_retained_002.xyz             : 1
# RR_CH2CO2Me_retained_ensemble.xyz        : 1
# RR_CMe2CO2Me_raw_crest_conformers.xyz    : 1
# RR_CMe2CO2Me_retained_001.xyz            : 1
# RR_CMe2CO2Me_retained_002.xyz            : 1
# RR_CMe2CO2Me_retained_ensemble.xyz       : 1
# RR_Cy_raw_crest_conformers.xyz           : 1
# RR_Cy_retained_001.xyz                   : 1
# RR_Cy_retained_002.xyz                   : 1
# RR_Cy_retained_003.xyz                   : 1
# RR_Cy_retained_ensemble.xyz              : 1
# RR_Et_raw_crest_conformers.xyz           : 1
# RR_Et_retained_001.xyz                   : 1
# RR_Et_retained_002.xyz                   : 1
# RR_Et_retained_ensemble.xyz              : 1
# RR_Me-Propane_raw_crest_conformers.xyz   : 1
# RR_Me-Propane_retained_001.xyz           : 1
# RR_Me-Propane_retained_ensemble.xyz      : 1
# RR_Me_raw_crest_conformers.xyz           : 1
# RR_Me_retained_001.xyz                   : 1
# RR_Me_retained_002.xyz                   : 1
# RR_Me_retained_ensemble.xyz              : 1
# RR_Ph_raw_crest_conformers.xyz           : 1
# RR_Ph_retained_001.xyz                   : 1
# RR_Ph_retained_002.xyz                   : 1
# RR_Ph_retained_ensemble.xyz              : 1
# RR_alkene_raw_crest_conformers.xyz       : 1
# RR_alkene_retained_001.xyz               : 1
# RR_alkene_retained_002.xyz               : 1
# RR_alkene_retained_003.xyz               : 1
# RR_alkene_retained_004.xyz               : 1
# RR_alkene_retained_ensemble.xyz          : 1
# RR_alkyne_raw_crest_conformers.xyz       : 1
# RR_alkyne_retained_001.xyz               : 1
# RR_alkyne_retained_002.xyz               : 1
# RR_alkyne_retained_003.xyz               : 1
# RR_alkyne_retained_ensemble.xyz          : 1
# RR_allyl_raw_crest_conformers.xyz        : 1
# RR_allyl_retained_001.xyz                : 1
# RR_allyl_retained_002.xyz                : 1
# RR_allyl_retained_ensemble.xyz           : 1
# RR_dimethyl-allyl_raw_crest_conformers.xyz : 1
# RR_dimethyl-allyl_retained_001.xyz       : 1
# RR_dimethyl-allyl_retained_002.xyz       : 1
# RR_dimethyl-allyl_retained_003.xyz       : 1
# RR_dimethyl-allyl_retained_ensemble.xyz  : 1
# RR_iPr_raw_crest_conformers.xyz          : 1
# RR_iPr_retained_001.xyz                  : 1
# RR_iPr_retained_002.xyz                  : 1
# RR_iPr_retained_003.xyz                  : 1
# RR_iPr_retained_004.xyz                  : 1
# RR_iPr_retained_ensemble.xyz             : 1
# RR_nBu_raw_crest_conformers.xyz          : 1
# RR_nBu_retained_001.xyz                  : 1
# RR_nBu_retained_002.xyz                  : 1
# RR_nBu_retained_ensemble.xyz             : 1
# RR_tBu_raw_crest_conformers.xyz          : 1
# RR_tBu_retained_001.xyz                  : 1
# RR_tBu_retained_002.xyz                  : 1
# RR_tBu_retained_003.xyz                  : 1
# RR_tBu_retained_ensemble.xyz             : 1
# RS_CH2-Ph_raw_crest_conformers.xyz       : 1
# RS_CH2-Ph_retained_001.xyz               : 1
# RS_CH2-Ph_retained_ensemble.xyz          : 1
# RS_CH2-dioxane_raw_crest_conformers.xyz  : 1
# RS_CH2-dioxane_retained_001.xyz          : 1
# RS_CH2-dioxane_retained_002.xyz          : 1
# RS_CH2-dioxane_retained_ensemble.xyz     : 1
# RS_CH2CN_raw_crest_conformers.xyz        : 1
# RS_CH2CN_retained_001.xyz                : 1
# RS_CH2CN_retained_ensemble.xyz           : 1
# RS_CH2CO2Me_raw_crest_conformers.xyz     : 1
# RS_CH2CO2Me_retained_001.xyz             : 1
# RS_CH2CO2Me_retained_002.xyz             : 1
# RS_CH2CO2Me_retained_ensemble.xyz        : 1
# RS_CMe2CO2Me_raw_crest_conformers.xyz    : 1
# RS_CMe2CO2Me_retained_001.xyz            : 1
# RS_CMe2CO2Me_retained_ensemble.xyz       : 1
# RS_Cy_raw_crest_conformers.xyz           : 1
# RS_Cy_retained_001.xyz                   : 1
# RS_Cy_retained_002.xyz                   : 1
# RS_Cy_retained_003.xyz                   : 1
# RS_Cy_retained_ensemble.xyz              : 1
# RS_Et_raw_crest_conformers.xyz           : 1
# RS_Et_retained_001.xyz                   : 1
# RS_Et_retained_002.xyz                   : 1
# RS_Et_retained_ensemble.xyz              : 1
# RS_Me-Propane_raw_crest_conformers.xyz   : 1
# RS_Me-Propane_retained_001.xyz           : 1
# RS_Me-Propane_retained_002.xyz           : 1
# RS_Me-Propane_retained_ensemble.xyz      : 1
# RS_Me_raw_crest_conformers.xyz           : 1
# RS_Me_retained_001.xyz                   : 1
# RS_Me_retained_002.xyz                   : 1
# RS_Me_retained_003.xyz                   : 1
# RS_Me_retained_ensemble.xyz              : 1
# RS_Ph_raw_crest_conformers.xyz           : 1
# RS_Ph_retained_001.xyz                   : 1
# RS_Ph_retained_002.xyz                   : 1
# RS_Ph_retained_003.xyz                   : 1
# RS_Ph_retained_004.xyz                   : 1
# RS_Ph_retained_ensemble.xyz              : 1
# RS_alkene_raw_crest_conformers.xyz       : 1
# RS_alkene_retained_001.xyz               : 1
# RS_alkene_retained_002.xyz               : 1
# RS_alkene_retained_003.xyz               : 1
# RS_alkene_retained_ensemble.xyz          : 1
# RS_alkyne_raw_crest_conformers.xyz       : 1
# RS_alkyne_retained_001.xyz               : 1
# RS_alkyne_retained_002.xyz               : 1
# RS_alkyne_retained_ensemble.xyz          : 1
# RS_allyl_raw_crest_conformers.xyz        : 1
# RS_allyl_retained_001.xyz                : 1
# RS_allyl_retained_002.xyz                : 1
# RS_allyl_retained_003.xyz                : 1
# RS_allyl_retained_ensemble.xyz           : 1
# RS_dimethyl-allyl_raw_crest_conformers.xyz : 1
# RS_dimethyl-allyl_retained_001.xyz       : 1
# RS_dimethyl-allyl_retained_002.xyz       : 1
# RS_dimethyl-allyl_retained_ensemble.xyz  : 1
# RS_iPr_raw_crest_conformers.xyz          : 1
# RS_iPr_retained_001.xyz                  : 1
# RS_iPr_retained_002.xyz                  : 1
# RS_iPr_retained_003.xyz                  : 1
# RS_iPr_retained_ensemble.xyz             : 1
# RS_nBu_raw_crest_conformers.xyz          : 1
# RS_nBu_retained_001.xyz                  : 1
# RS_nBu_retained_002.xyz                  : 1
# RS_nBu_retained_003.xyz                  : 1
# RS_nBu_retained_004.xyz                  : 1
# RS_nBu_retained_ensemble.xyz             : 1
# RS_tBu_raw_crest_conformers.xyz          : 1
# RS_tBu_retained_001.xyz                  : 1
# RS_tBu_retained_002.xyz                  : 1
# RS_tBu_retained_003.xyz                  : 1
# RS_tBu_retained_ensemble.xyz             : 1
